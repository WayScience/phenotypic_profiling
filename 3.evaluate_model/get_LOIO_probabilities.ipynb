# %% [markdown]
# ### Load Libraries

# %%
import pathlib
import warnings
import sys
import itertools

import numpy as np
import pandas as pd
from joblib import load

from sklearn.linear_model import LogisticRegression
from sklearn.utils import parallel_backend
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import f1_score

sys.path.append("../utils")
from split_utils import get_features_data
from train_utils import get_X_y_data
from evaluate_utils import get_SCM_model_data

# %% [markdown]
# ### Load/Preview Labeled Data

# %%
# load labeled data
labeled_data_path = pathlib.Path("../0.download_data/data/labeled_data.csv.gz")
labeled_data = get_features_data(labeled_data_path)

# preview labeled data
print(labeled_data.shape)
labeled_data.head(5)
# Out:
# (2862, 1450)
#   Mitocheck_Phenotypic_Class                             Cell_UUID  \
# 0                      Large  21da27ab-873a-41f4-ab98-49170cae9a2d
# 1                      Large  82f7949b-4ea2-45c8-8dd9-7854caf49077
# 2                      Large  cec7234f-fe35-4411-aded-f8112bb31219
# 3                      Large  43d9e7c9-c9ec-45ce-8820-048bfb896989
# 4                      Large  63ce6652-338e-4afd-9c77-dbc0e903bf92
#
#    Location_Center_X  Location_Center_Y Metadata_Plate  Metadata_Well  \
# 0                397                618      LT0010_27            173
# 1                359                584      LT0010_27            173
# 2                383                685      LT0010_27            173
# 3                932                532      LT0013_38             42
# 4                477                130      LT0013_38             42
#
#    Metadata_Frame  Metadata_Site Metadata_Plate_Map_Name  \
# 0              83              1           LT0010_27_173
# 1              83              1           LT0010_27_173
# 2              83              1           LT0010_27_173
# 3              75              1            LT0013_38_42
# 4              75              1            LT0013_38_42
#
#                      Metadata_DNA  ... DP__efficientnet_1270  \
# 0  LT0010_27/LT0010_27_173_83.tif  ...              1.526493
# 1  LT0010_27/LT0010_27_173_83.tif  ...             -0.482883
# 2  LT0010_27/LT0010_27_173_83.tif  ...              0.888706
# 3   LT0013_38/LT0013_38_42_75.tif  ...             -1.001625
# 4   LT0013_38/LT0013_38_42_75.tif  ...              0.950706
#
#    DP__efficientnet_1271 DP__efficientnet_1272  DP__efficientnet_1273  \
# 0              -0.388909             -0.715202              -0.939279
# 1              -1.354858             -0.856680              -0.934949
# 2               1.350431             -0.648841               0.264205
# 3              -0.801021             -0.586539               0.076197
# 4              -0.811825             -0.522427              -1.402842
#
#    DP__efficientnet_1274  DP__efficientnet_1275  DP__efficientnet_1276  \
# 0              -0.077689               1.965509              18.685819
# 1               0.725091               2.255450              -0.565433
# 2               0.131341               0.678315               0.171044
# 3               0.599191               1.742090               0.365520
# 4              -0.289940               2.661250               0.126978
#
#    DP__efficientnet_1277  DP__efficientnet_1278  DP__efficientnet_1279
# 0               0.061676               2.641369              -0.086854
# 1               1.628086              -0.605625              -0.748135
# 2               0.342206              -0.581597               0.505556
# 3               0.643759              -1.906097               1.019370
# 4              -0.824945              -0.494285               1.763332
#
# [5 rows x 1450 columns]

# %%
# see number of images to
num_images = labeled_data["Metadata_DNA"].unique().shape[0]
print(f"There are {num_images} images to perform LOIO evaluation on per model.")
# Out:
# There are 270 images to perform LOIO evaluation on per model.

# %% [markdown]
# ### Get LOIO probabilities (multi class models)

# %%
# directory to load the models from
models_dir = pathlib.Path("../2.train_model/models/multi_class_models")

# use a list to keep track of LOIO probabilities in tidy long format for each model combination
compiled_LOIO_wide_data = []

# iterate through each model (final model, shuffled baseline model, etc)
# sorted so final models are loaded before shuffled_baseline
for model_path in sorted(models_dir.iterdir()):
    # determine model/feature type/balance type from model file name
    model_components = model_path.name.split("__")
    # Older models only have 2 components, skip these
    if len(model_components) == 2:
        continue
    model_type = model_components[0]
    feature_type = model_components[1]
    balance_type = model_components[2].replace(".joblib", "")
    if balance_type == "balanced":
        balance_model = "balanced"
    else:
        balance_model = None
    # Load the model
    model = load(model_path)
    
    print(
        f"Performing LOIO for model {model_type} with balance type {balance_type} and feature type {feature_type} with parameters C: {model.C}, l1_ratio: {model.l1_ratio}"
    )

    if feature_type == "CP_zernike_only":
        zernike_only = True
        dataset = "CP"
    else:
        zernike_only = False
        dataset = feature_type
        
    if feature_type == "CP_areashape_only":
        area_shape_only = True
        dataset = "CP"
    else:
        area_shape_only = False
    
    # iterate through image paths
    for image_path in labeled_data["Metadata_DNA"].unique():
        # get training and testing cells from image path
        # every cell from the image path is for testing, the rest are for training
        train_cells = labeled_data.loc[labeled_data["Metadata_DNA"] != image_path]
        test_cells = labeled_data.loc[labeled_data["Metadata_DNA"] == image_path]

        # get X, y from training and testing cells
        X_train, y_train = get_X_y_data(train_cells, dataset, zernike_only, area_shape_only)
        X_test, y_test = get_X_y_data(test_cells, dataset, zernike_only, area_shape_only)
        
        # shuffle columns of X (features) dataframe independently to create shuffled baseline
        if model_type == "shuffled_baseline":
            for column in X_train.T:
                np.random.shuffle(column)

        # capture convergence warning from sklearn
        # this warning does not affect the model but takes up lots of space in the output
        # this warning must be caught with parallel_backend because the logistic regression model uses parallel_backend
        # (n_jobs=-1 means use all processors)
        with parallel_backend("multiprocessing"):
            with warnings.catch_warnings():
                warnings.filterwarnings(
                    "ignore", category=ConvergenceWarning, module="sklearn"
                )

                # fit a logisitc regression model on the training X, y
                LOIO_model = LogisticRegression(
                    penalty="elasticnet",
                    solver="saga",
                    class_weight=balance_model,
                    max_iter=100,
                    n_jobs=-1,
                    random_state=0,
                    C=model.C,
                    l1_ratio=model.l1_ratio,
                ).fit(X_train, y_train)

        # create metadata dataframe for test cells with model parameters
        metadata_dataframe = pd.concat(
            [
                test_cells["Cell_UUID"],
                test_cells["Metadata_DNA"],
                test_cells["Mitocheck_Phenotypic_Class"],
            ],
            axis=1,
        ).reset_index(drop=True)
        metadata_dataframe["Model_Type"] = model_type
        metadata_dataframe["Model_Feature_Type"] = feature_type
        metadata_dataframe["Model_Balance_Type"] = balance_type
        metadata_dataframe["Model_C"] = model.C
        metadata_dataframe["Model_l1_ratio"] = model.l1_ratio

        # predict probabilities for test cells and make these probabilities into a dataframe
        probas = LOIO_model.predict_proba(X_test)
        probas_dataframe = pd.DataFrame(probas, columns=model.classes_)

        # combine metadata and probabilities dataframes for test cells to create wide data
        test_cells_wide_data = pd.concat([metadata_dataframe, probas_dataframe], axis=1)

        # add tidy long data to compiled data
        compiled_LOIO_wide_data.append(test_cells_wide_data)
# Out:
# Performing LOIO for model final with balance type balanced and feature type CP with parameters C: 1.0, l1_ratio: 0.8
# Performing LOIO for model final with balance type unbalanced and feature type CP with parameters C: 10.0, l1_ratio: 0.2
# Performing LOIO for model final with balance type balanced and feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.30000000000000004
# Performing LOIO for model final with balance type unbalanced and feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.30000000000000004
# Performing LOIO for model final with balance type balanced and feature type CP_areashape_only with parameters C: 0.1, l1_ratio: 0.4
# Performing LOIO for model final with balance type unbalanced and feature type CP_areashape_only with parameters C: 1.0, l1_ratio: 1.0
# Performing LOIO for model final with balance type balanced and feature type CP_zernike_only with parameters C: 0.1, l1_ratio: 0.30000000000000004
# Performing LOIO for model final with balance type unbalanced and feature type CP_zernike_only with parameters C: 1.0, l1_ratio: 1.0
# Performing LOIO for model final with balance type balanced and feature type DP with parameters C: 10.0, l1_ratio: 0.5
# Performing LOIO for model final with balance type unbalanced and feature type DP with parameters C: 1.0, l1_ratio: 1.0
# Performing LOIO for model shuffled_baseline with balance type balanced and feature type CP with parameters C: 10.0, l1_ratio: 0.2
# Performing LOIO for model shuffled_baseline with balance type unbalanced and feature type CP with parameters C: 0.01, l1_ratio: 0.0
# Performing LOIO for model shuffled_baseline with balance type balanced and feature type CP_and_DP with parameters C: 1.0, l1_ratio: 1.0
# Performing LOIO for model shuffled_baseline with balance type unbalanced and feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.8
# Performing LOIO for model shuffled_baseline with balance type balanced and feature type CP_areashape_only with parameters C: 100.0, l1_ratio: 0.0
# Performing LOIO for model shuffled_baseline with balance type unbalanced and feature type CP_areashape_only with parameters C: 100.0, l1_ratio: 0.1
# Performing LOIO for model shuffled_baseline with balance type balanced and feature type CP_zernike_only with parameters C: 0.01, l1_ratio: 0.0
# Performing LOIO for model shuffled_baseline with balance type unbalanced and feature type CP_zernike_only with parameters C: 0.1, l1_ratio: 0.2
# Performing LOIO for model shuffled_baseline with balance type balanced and feature type DP with parameters C: 0.1, l1_ratio: 0.2
# Performing LOIO for model shuffled_baseline with balance type unbalanced and feature type DP with parameters C: 1.0, l1_ratio: 0.8

# %% [markdown]
# ### Format and save LOIO probabilities (multi class models)

# %%
# compile list of wide data into one dataframe
compiled_LOIO_wide_data = pd.concat(compiled_LOIO_wide_data).reset_index(drop=True)

# convert wide data to tidy long data and sort by Cell_UUID, Model_Feature_Type, and Model_Phenotypic_Class for pretty formatting
compiled_LOIO_tidy_long_data = (
    pd.melt(
        compiled_LOIO_wide_data,
        id_vars=metadata_dataframe.columns,
        value_vars=probas_dataframe.columns,
        var_name="Model_Phenotypic_Class",
        value_name="Predicted_Probability",
    )
    .sort_values(["Model_Feature_Type", "Cell_UUID", "Model_Phenotypic_Class"])
    .reset_index(drop=True)
)

# specify results directory
LOIO_probas_dir = pathlib.Path("evaluations/LOIO_probas/")
LOIO_probas_dir.mkdir(parents=True, exist_ok=True)

# define save path
compiled_LOIO_save_path = pathlib.Path(
    f"{LOIO_probas_dir}/compiled_LOIO_probabilites.tsv"
)

# save data as tsv
compiled_LOIO_tidy_long_data.to_csv(compiled_LOIO_save_path, sep="\t")

# preview tidy long data
compiled_LOIO_tidy_long_data
# Out:
#                                    Cell_UUID                    Metadata_DNA  \
# 0       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 1       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 2       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 3       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 4       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# ...                                      ...                             ...
# 858595  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 858596  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 858597  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 858598  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 858599  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
#
#        Mitocheck_Phenotypic_Class         Model_Type Model_Feature_Type  \
# 0                      Interphase              final                 CP
# 1                      Interphase              final                 CP
# 2                      Interphase  shuffled_baseline                 CP
# 3                      Interphase  shuffled_baseline                 CP
# 4                      Interphase              final                 CP
# ...                           ...                ...                ...
# 858595               Prometaphase  shuffled_baseline                 DP
# 858596               Prometaphase              final                 DP
# 858597               Prometaphase              final                 DP
# 858598               Prometaphase  shuffled_baseline                 DP
# 858599               Prometaphase  shuffled_baseline                 DP
#
#        Model_Balance_Type  Model_C  Model_l1_ratio Model_Phenotypic_Class  \
# 0                balanced     1.00             0.8                  ADCCM
# 1              unbalanced    10.00             0.2                  ADCCM
# 2                balanced    10.00             0.2                  ADCCM
# 3              unbalanced     0.01             0.0                  ADCCM
# 4                balanced     1.00             0.8               Anaphase
# ...                   ...      ...             ...                    ...
# 858595         unbalanced     1.00             0.8           Prometaphase
# 858596           balanced    10.00             0.5         SmallIrregular
# 858597         unbalanced     1.00             1.0         SmallIrregular
# 858598           balanced     0.10             0.2         SmallIrregular
# 858599         unbalanced     1.00             0.8         SmallIrregular
#
#         Predicted_Probability
# 0                8.095604e-06
# 1                5.697936e-06
# 2                5.920815e-01
# 3                2.784475e-02
# 4                2.752629e-01
# ...                       ...
# 858595           8.206371e-01
# 858596           1.901829e-08
# 858597           3.970684e-08
# 858598           6.513654e-03
# 858599           7.692054e-05
#
# [858600 rows x 10 columns]

# %% [markdown]
# ### Get LOIO probabilities (single class models)

# %%
# directory to load the models from
models_dir = pathlib.Path("../2.train_model/models/single_class_models")

# use a list to keep track of LOIO probabilities in tidy long format for each model combination
compiled_LOIO_wide_data = []

# define combinations to test over
model_types = [
    "final"
]  # only perform LOIO with hyper params from final models so skip shuffled_baseline models
feature_types = ["CP", "DP", "CP_and_DP"]
phenotypic_classes = labeled_data["Mitocheck_Phenotypic_Class"].unique()

# iterate through each combination of feature_types, evaluation_types, phenotypic_classes
for model_type, feature_type, phenotypic_class in itertools.product(
    model_types, feature_types, phenotypic_classes
):
    single_class_model_path = pathlib.Path(
        f"{models_dir}/{phenotypic_class}_models/{model_type}__{feature_type}.joblib"
    )

    # load the model
    model = load(single_class_model_path)

    print(
        f"Performing LOIO on {phenotypic_class} model for feature type {feature_type} with parameters C: {model.C}, l1_ratio: {model.l1_ratio}"
    )

    # iterate through image paths
    for image_path in labeled_data["Metadata_DNA"].unique():
        # get training and testing cells from image path
        # every cell from the image path is for testing, the rest are for training
        train_cells = labeled_data.loc[labeled_data["Metadata_DNA"] != image_path]
        test_cells = labeled_data.loc[labeled_data["Metadata_DNA"] == image_path]

        # rename negative label and downsample over represented classes
        train_cells = get_SCM_model_data(train_cells, phenotypic_class, "train")
        test_cells = get_SCM_model_data(test_cells, phenotypic_class, "test")

        # get X, y from training and testing cells
        X_train, y_train = get_X_y_data(train_cells, feature_type)
        X_test, y_test = get_X_y_data(test_cells, feature_type)

        # capture convergence warning from sklearn
        # this warning does not affect the model but takes up lots of space in the output
        # this warning must be caught with parallel_backend because the logistic regression model uses parallel_backend
        # (n_jobs=-1 means use all processors)
        with parallel_backend("multiprocessing"):
            with warnings.catch_warnings():
                warnings.filterwarnings(
                    "ignore", category=ConvergenceWarning, module="sklearn"
                )

                # fit a logisitc regression model on the training X, y
                LOIO_model = LogisticRegression(
                    penalty="elasticnet",
                    solver="saga",
                    max_iter=100,
                    n_jobs=-1,
                    random_state=0,
                    C=model.C,
                    l1_ratio=model.l1_ratio,
                ).fit(X_train, y_train)

        # create metadata dataframe for test cells with model parameters
        metadata_dataframe = pd.concat(
            [
                test_cells["Cell_UUID"],
                test_cells["Metadata_DNA"],
                test_cells["Mitocheck_Phenotypic_Class"],
            ],
            axis=1,
        ).reset_index(drop=True)
        metadata_dataframe["Model_Feature_Type"] = feature_type
        metadata_dataframe["Model_C"] = model.C
        metadata_dataframe["Model_l1_ratio"] = model.l1_ratio
        metadata_dataframe["Model_Phenotypic_Class"] = phenotypic_class

        # predict probabilities for test cells and make these probabilities into a dataframe
        probas = LOIO_model.predict_proba(X_test)
        probas_dataframe = pd.DataFrame(probas, columns=model.classes_)
        # make column names consistent for all single cell models (SCMs)
        # positive label corresponds to that SCM's phenotypic class, negative is all other labels
        probas_dataframe = probas_dataframe.rename(
            columns={
                phenotypic_class: "Positive_Label",
                f"Not {phenotypic_class}": "Negative_Label",
            }
        )

        # combine metadata and probabilities dataframes for test cells to create wide data
        test_cells_wide_data = pd.concat([metadata_dataframe, probas_dataframe], axis=1)

        # add tidy long data to compiled data
        compiled_LOIO_wide_data.append(test_cells_wide_data)
# Out:
# Performing LOIO on Large model for feature type CP with parameters C: 0.01, l1_ratio: 0.1
# Performing LOIO on Prometaphase model for feature type CP with parameters C: 1.0, l1_ratio: 0.5
# Performing LOIO on Grape model for feature type CP with parameters C: 0.01, l1_ratio: 0.0
# Performing LOIO on Interphase model for feature type CP with parameters C: 1.0, l1_ratio: 0.6000000000000001
# Performing LOIO on Apoptosis model for feature type CP with parameters C: 0.01, l1_ratio: 0.1
# Performing LOIO on ADCCM model for feature type CP with parameters C: 0.01, l1_ratio: 0.2
# Performing LOIO on SmallIrregular model for feature type CP with parameters C: 1.0, l1_ratio: 0.2
# Performing LOIO on Polylobed model for feature type CP with parameters C: 0.1, l1_ratio: 0.6000000000000001
# Performing LOIO on Metaphase model for feature type CP with parameters C: 0.1, l1_ratio: 0.2
# Performing LOIO on Binuclear model for feature type CP with parameters C: 0.1, l1_ratio: 0.0
# Performing LOIO on Hole model for feature type CP with parameters C: 0.01, l1_ratio: 0.1
# Performing LOIO on Anaphase model for feature type CP with parameters C: 0.1, l1_ratio: 0.30000000000000004
# Performing LOIO on MetaphaseAlignment model for feature type CP with parameters C: 0.1, l1_ratio: 0.5
# Performing LOIO on Elongated model for feature type CP with parameters C: 0.1, l1_ratio: 0.1
# Performing LOIO on OutOfFocus model for feature type CP with parameters C: 0.01, l1_ratio: 0.30000000000000004
# Performing LOIO on Large model for feature type DP with parameters C: 0.1, l1_ratio: 0.8
# Performing LOIO on Prometaphase model for feature type DP with parameters C: 0.01, l1_ratio: 0.0
# Performing LOIO on Grape model for feature type DP with parameters C: 0.01, l1_ratio: 0.2
# Performing LOIO on Interphase model for feature type DP with parameters C: 0.1, l1_ratio: 0.6000000000000001
# Performing LOIO on Apoptosis model for feature type DP with parameters C: 0.1, l1_ratio: 1.0
# Performing LOIO on ADCCM model for feature type DP with parameters C: 0.1, l1_ratio: 0.5
# Performing LOIO on SmallIrregular model for feature type DP with parameters C: 0.01, l1_ratio: 0.2
# Performing LOIO on Polylobed model for feature type DP with parameters C: 0.1, l1_ratio: 0.4
# Performing LOIO on Metaphase model for feature type DP with parameters C: 0.1, l1_ratio: 0.4
# Performing LOIO on Binuclear model for feature type DP with parameters C: 0.1, l1_ratio: 0.0
# Performing LOIO on Hole model for feature type DP with parameters C: 0.01, l1_ratio: 0.0
# Performing LOIO on Anaphase model for feature type DP with parameters C: 0.01, l1_ratio: 0.0
# Performing LOIO on MetaphaseAlignment model for feature type DP with parameters C: 0.01, l1_ratio: 0.30000000000000004
# Performing LOIO on Elongated model for feature type DP with parameters C: 0.1, l1_ratio: 0.30000000000000004
# Performing LOIO on OutOfFocus model for feature type DP with parameters C: 0.01, l1_ratio: 0.30000000000000004
# Performing LOIO on Large model for feature type CP_and_DP with parameters C: 1.0, l1_ratio: 0.1
# Performing LOIO on Prometaphase model for feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.5
# Performing LOIO on Grape model for feature type CP_and_DP with parameters C: 0.01, l1_ratio: 0.2
# Performing LOIO on Interphase model for feature type CP_and_DP with parameters C: 0.1, l1_ratio: 1.0
# Performing LOIO on Apoptosis model for feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.2
# Performing LOIO on ADCCM model for feature type CP_and_DP with parameters C: 0.01, l1_ratio: 0.0
# Performing LOIO on SmallIrregular model for feature type CP_and_DP with parameters C: 1.0, l1_ratio: 0.8
# Performing LOIO on Polylobed model for feature type CP_and_DP with parameters C: 0.01, l1_ratio: 0.7000000000000001
# Performing LOIO on Metaphase model for feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.2
# Performing LOIO on Binuclear model for feature type CP_and_DP with parameters C: 1.0, l1_ratio: 1.0
# Performing LOIO on Hole model for feature type CP_and_DP with parameters C: 1.0, l1_ratio: 0.30000000000000004
# Performing LOIO on Anaphase model for feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.8
# Performing LOIO on MetaphaseAlignment model for feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.9
# Performing LOIO on Elongated model for feature type CP_and_DP with parameters C: 0.1, l1_ratio: 0.8
# Performing LOIO on OutOfFocus model for feature type CP_and_DP with parameters C: 0.001, l1_ratio: 0.1

# %% [markdown]
# ### Format and save LOIO probabilities (single class models)

# %%
# compile list of wide data into one dataframe
compiled_LOIO_wide_data = pd.concat(compiled_LOIO_wide_data).reset_index(drop=True)

# convert wide data to tidy long data and sort by Cell_UUID, Model_Feature_Type, and Model_Phenotypic_Class for pretty formatting
compiled_LOIO_tidy_long_data = (
    pd.melt(
        compiled_LOIO_wide_data,
        id_vars=metadata_dataframe.columns,
        value_vars=probas_dataframe.columns,
        var_name="Predicted_Label",
        value_name="Predicted_Probability",
    )
    .sort_values(["Model_Feature_Type", "Cell_UUID", "Model_Phenotypic_Class"])
    .reset_index(drop=True)
)

# specify results directory
LOIO_probas_dir = pathlib.Path("evaluations/LOIO_probas/")
LOIO_probas_dir.mkdir(parents=True, exist_ok=True)

# define save path
compiled_LOIO_save_path = pathlib.Path(
    f"{LOIO_probas_dir}/compiled_SCM_LOIO_probabilites.tsv"
)

# save data as tsv
compiled_LOIO_tidy_long_data.to_csv(compiled_LOIO_save_path, sep="\t")

# preview tidy long data
compiled_LOIO_tidy_long_data
# Out:
#                                    Cell_UUID                    Metadata_DNA  \
# 0       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 1       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 2       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 3       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# 4       0008551d-e7f6-4351-b680-140c3661cb59  LT0109_38/LT0109_38_381_87.tif
# ...                                      ...                             ...
# 257575  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 257576  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 257577  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 257578  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
# 257579  fffe7b67-9876-4ef0-9848-046506e8f238  LT0035_06/LT0035_06_274_21.tif
#
#        Mitocheck_Phenotypic_Class Model_Feature_Type  Model_C  Model_l1_ratio  \
# 0                  ADCCM Negative                 CP     0.01             0.2
# 1                  ADCCM Negative                 CP     0.01             0.2
# 2               Anaphase Negative                 CP     0.10             0.3
# 3               Anaphase Negative                 CP     0.10             0.3
# 4              Apoptosis Negative                 CP     0.01             0.1
# ...                           ...                ...      ...             ...
# 257575         Polylobed Negative                 DP     0.10             0.4
# 257576               Prometaphase                 DP     0.01             0.0
# 257577               Prometaphase                 DP     0.01             0.0
# 257578    SmallIrregular Negative                 DP     0.01             0.2
# 257579    SmallIrregular Negative                 DP     0.01             0.2
#
#        Model_Phenotypic_Class      Predicted_Label  Predicted_Probability
# 0                       ADCCM       Positive_Label               0.366999
# 1                       ADCCM  OutOfFocus Negative                    NaN
# 2                    Anaphase       Positive_Label               0.922529
# 3                    Anaphase  OutOfFocus Negative                    NaN
# 4                   Apoptosis       Positive_Label               0.959497
# ...                       ...                  ...                    ...
# 257575              Polylobed  OutOfFocus Negative                    NaN
# 257576           Prometaphase       Positive_Label               0.993936
# 257577           Prometaphase  OutOfFocus Negative                    NaN
# 257578         SmallIrregular       Positive_Label               0.105574
# 257579         SmallIrregular  OutOfFocus Negative                    NaN
#
# [257580 rows x 9 columns]
