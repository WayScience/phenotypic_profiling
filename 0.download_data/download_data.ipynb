# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import pathlib

import sys
sys.path.append("../utils")
from download_utils import combine_datasets

# %% [markdown]
# ### Specify version of mitocheck_data to download from

# %%
hash_2006 = "19bfa5b0959d6b7536f83e7bb85745ba3edf7ff9"
file_url_2006 = f"https://raw.github.com/WayScience/mitocheck_data/{hash_2006}/3.normalize_data/normalized_data/training_data.csv.gz"

hash_2015 = "3ebd0ca7c288f608e9b23987a8ddbabd5476bd8f"
file_url_2015 = f"https://raw.github.com/WayScience/mitocheck_data/{hash_2015}/3.normalize_data/normalized_data/training_data.csv.gz"

# %% [markdown]
# ### Load/combine training data from github

# %%
training_data_2006 = pd.read_csv(file_url_2006, compression="gzip", index_col=0)
# remove unnecessary mitocheck object ID as this ID is not present for data repeated in 2015 dataset
training_data_2006 = training_data_2006.drop(columns=["Mitocheck_Object_ID"])

training_data_2015 = pd.read_csv(file_url_2015, compression="gzip", index_col=0)

# %%
training_data_2006
# Out:
#      Mitocheck_Phenotypic_Class  Location_Center_X  Location_Center_Y  \
# 0            MetaphaseAlignment         572.214286          58.185714
# 1                      Artefact        1117.070423         342.732394
# 2                      Artefact        1116.500000         362.000000
# 3                      Artefact        1106.348485         370.469697
# 4            MetaphaseAlignment         937.692308         521.048077
# ...                         ...                ...                ...
# 4648             SmallIrregular        1065.846154         570.123077
# 4649             SmallIrregular        1095.894737         580.771930
# 4650             SmallIrregular         323.269231         622.641026
# 4651             SmallIrregular         368.027397         893.575342
# 4652             SmallIrregular         348.283784         934.040541
#
#      Metadata_Plate  Metadata_Well  Metadata_Frame  Metadata_Site  \
# 0         LT0066_19            287               1              1
# 1         LT0066_19            287               1              1
# 2         LT0066_19            287               1              1
# 3         LT0066_19            287               1              1
# 4         LT0066_19            287               1              1
# ...             ...            ...             ...            ...
# 4648      LT0030_17            184              39              1
# 4649      LT0030_17            184              39              1
# 4650      LT0030_17            184              39              1
# 4651      LT0030_17            184              39              1
# 4652      LT0030_17            184              39              1
#
#      Metadata_Plate_Map_Name                    Metadata_DNA Metadata_Gene  \
# 0              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 1              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 2              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 3              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 4              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# ...                      ...                             ...           ...
# 4648           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif           RGR
# 4649           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif           RGR
# 4650           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif           RGR
# 4651           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif           RGR
# 4652           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif           RGR
#
#       ...  efficientnet_1270 efficientnet_1271  efficientnet_1272  \
# 0     ...           1.048350         -0.721622           0.749788
# 1     ...           1.172767         -0.290257          -0.709041
# 2     ...           1.093582         -0.323180          -0.663069
# 3     ...           0.943948         -0.211267          -0.346355
# 4     ...           0.947300         -0.564136           0.333336
# ...   ...                ...               ...                ...
# 4648  ...          -0.691697          0.809051          -0.522286
# 4649  ...           0.014888          2.423067          -0.530521
# 4650  ...           1.127832          0.492408          -0.531921
# 4651  ...           0.410533          1.964066          -0.833740
# 4652  ...          -0.041231          0.998568           0.006131
#
#       efficientnet_1273  efficientnet_1274  efficientnet_1275  \
# 0             -1.377590           0.454974           0.188488
# 1             -1.431541          -0.063308          -0.412793
# 2             -1.427502          -0.901764          -0.355080
# 3             -1.365543          -0.276932           0.023856
# 4             -1.584454           0.891666           1.223252
# ...                 ...                ...                ...
# 4648          -0.956816           0.112946          -0.087137
# 4649          -1.026853           0.021895          -0.550902
# 4650          -0.766331           0.286463           0.493081
# 4651          -0.246026           0.984373           0.755903
# 4652          -0.857846           1.163148           0.904470
#
#       efficientnet_1276  efficientnet_1277  efficientnet_1278  \
# 0              0.141427          -1.553405           2.346107
# 1              0.452684          -1.906647           1.962141
# 2              0.418053          -2.298449           1.098266
# 3              0.376514          -1.700348           1.833686
# 4             -0.359166          -0.826366           2.115734
# ...                 ...                ...                ...
# 4648          -1.078033           0.191389          -0.921300
# 4649          -1.224869          -0.410984          -0.717952
# 4650           0.520599          -0.713538           0.553553
# 4651           0.129754          -0.148277          -0.587435
# 4652          -0.321917           0.480036           0.449932
#
#       efficientnet_1279
# 0             -1.774278
# 1             -0.223039
# 2             -0.069326
# 3             -0.625385
# 4             -1.241848
# ...                 ...
# 4648           1.250694
# 4649           2.297320
# 4650           0.480614
# 4651           2.032008
# 4652           1.926145
#
# [4653 rows x 1292 columns]

# %%
training_data = combine_datasets(training_data_2006, training_data_2015)
# Out:
# Cell found in both datasets! Index 3 in 2015 data.
# Cell found in both datasets! Index 5 in 2015 data.
# Cell found in both datasets! Index 6 in 2015 data.
# Cell found in both datasets! Index 7 in 2015 data.
# Cell found in both datasets! Index 8 in 2015 data.
# Cell found in both datasets! Index 10 in 2015 data.
# Cell found in both datasets! Index 11 in 2015 data.
# Cell found in both datasets! Index 12 in 2015 data.
# Cell found in both datasets! Index 13 in 2015 data.
# Cell found in both datasets! Index 14 in 2015 data.
# Cell found in both datasets! Index 15 in 2015 data.
# Cell found in both datasets! Index 16 in 2015 data.
# Cell found in both datasets! Index 17 in 2015 data.
# Cell found in both datasets! Index 18 in 2015 data.
# Cell found in both datasets! Index 19 in 2015 data.
# Cell found in both datasets! Index 20 in 2015 data.
# Cell found in both datasets! Index 21 in 2015 data.
# Cell found in both datasets! Index 22 in 2015 data.
# Cell found in both datasets! Index 23 in 2015 data.
# Cell found in both datasets! Index 24 in 2015 data.
# Cell found in both datasets! Index 25 in 2015 data.
# Cell found in both datasets! Index 27 in 2015 data.
# Cell found in both datasets! Index 28 in 2015 data.
# Cell found in both datasets! Index 29 in 2015 data.
# Cell found in both datasets! Index 30 in 2015 data.
# Cell found in both datasets! Index 31 in 2015 data.
# Cell found in both datasets! Index 32 in 2015 data.
# Cell found in both datasets! Index 33 in 2015 data.
# Cell found in both datasets! Index 34 in 2015 data.
# Cell found in both datasets! Index 35 in 2015 data.
# Cell found in both datasets! Index 39 in 2015 data.
# Cell found in both datasets! Index 40 in 2015 data.
# Cell found in both datasets! Index 41 in 2015 data.
# Cell found in both datasets! Index 43 in 2015 data.
# Cell found in both datasets! Index 44 in 2015 data.
# Cell found in both datasets! Index 45 in 2015 data.
# Cell found in both datasets! Index 46 in 2015 data.
# Cell found in both datasets! Index 47 in 2015 data.
# Cell found in both datasets! Index 48 in 2015 data.
# Cell found in both datasets! Index 49 in 2015 data.
# Cell found in both datasets! Index 73 in 2015 data.
# Cell found in both datasets! Index 74 in 2015 data.
# Cell found in both datasets! Index 75 in 2015 data.
# Cell found in both datasets! Index 76 in 2015 data.
# Cell found in both datasets! Index 77 in 2015 data.
# Cell found in both datasets! Index 78 in 2015 data.
# Cell found in both datasets! Index 79 in 2015 data.
# Cell found in both datasets! Index 80 in 2015 data.
# Cell found in both datasets! Index 81 in 2015 data.
# Cell found in both datasets! Index 82 in 2015 data.
# Cell found in both datasets! Index 83 in 2015 data.
# Cell found in both datasets! Index 84 in 2015 data.
# Cell found in both datasets! Index 85 in 2015 data.
# Cell found in both datasets! Index 86 in 2015 data.
# Cell found in both datasets! Index 87 in 2015 data.
# Cell found in both datasets! Index 88 in 2015 data.
# Cell found in both datasets! Index 89 in 2015 data.
# Cell found in both datasets! Index 90 in 2015 data.
# Cell found in both datasets! Index 91 in 2015 data.
# Cell found in both datasets! Index 92 in 2015 data.
# Cell found in both datasets! Index 93 in 2015 data.
# Cell found in both datasets! Index 94 in 2015 data.
# Cell found in both datasets! Index 95 in 2015 data.
# Cell found in both datasets! Index 96 in 2015 data.
# Cell found in both datasets! Index 97 in 2015 data.
# Cell found in both datasets! Index 98 in 2015 data.
# Cell found in both datasets! Index 99 in 2015 data.
# Cell found in both datasets! Index 100 in 2015 data.
# Cell found in both datasets! Index 101 in 2015 data.
# Cell found in both datasets! Index 102 in 2015 data.
# Cell found in both datasets! Index 103 in 2015 data.
# Cell found in both datasets! Index 104 in 2015 data.
# Cell found in both datasets! Index 105 in 2015 data.
# Cell found in both datasets! Index 106 in 2015 data.
# Cell found in both datasets! Index 107 in 2015 data.
# Cell found in both datasets! Index 108 in 2015 data.
# Cell found in both datasets! Index 109 in 2015 data.
# Cell found in both datasets! Index 110 in 2015 data.
# Cell found in both datasets! Index 111 in 2015 data.
# Cell found in both datasets! Index 112 in 2015 data.
# Cell found in both datasets! Index 113 in 2015 data.
# Cell found in both datasets! Index 114 in 2015 data.
# Cell found in both datasets! Index 115 in 2015 data.
# Cell found in both datasets! Index 116 in 2015 data.
# Cell found in both datasets! Index 117 in 2015 data.
# Cell found in both datasets! Index 118 in 2015 data.
# Cell found in both datasets! Index 119 in 2015 data.
# Cell found in both datasets! Index 120 in 2015 data.
# Cell found in both datasets! Index 121 in 2015 data.
# Cell found in both datasets! Index 122 in 2015 data.
# Cell found in both datasets! Index 123 in 2015 data.
# Cell found in both datasets! Index 124 in 2015 data.
# Cell found in both datasets! Index 127 in 2015 data.
# Cell found in both datasets! Index 128 in 2015 data.
# Cell found in both datasets! Index 129 in 2015 data.
# Cell found in both datasets! Index 130 in 2015 data.
# Cell found in both datasets! Index 131 in 2015 data.
# Cell found in both datasets! Index 132 in 2015 data.
# Cell found in both datasets! Index 133 in 2015 data.
# Cell found in both datasets! Index 134 in 2015 data.
# Cell found in both datasets! Index 135 in 2015 data.
# Cell found in both datasets! Index 136 in 2015 data.
# Cell found in both datasets! Index 137 in 2015 data.
# Cell found in both datasets! Index 138 in 2015 data.
# Cell found in both datasets! Index 139 in 2015 data.
# Cell found in both datasets! Index 140 in 2015 data.
# Cell found in both datasets! Index 141 in 2015 data.
# Cell found in both datasets! Index 142 in 2015 data.
# Cell found in both datasets! Index 143 in 2015 data.
# Cell found in both datasets! Index 144 in 2015 data.
# Cell found in both datasets! Index 145 in 2015 data.
# Cell found in both datasets! Index 146 in 2015 data.
# Cell found in both datasets! Index 147 in 2015 data.
# Cell found in both datasets! Index 148 in 2015 data.
# Cell found in both datasets! Index 149 in 2015 data.
# Cell found in both datasets! Index 150 in 2015 data.
# Cell found in both datasets! Index 151 in 2015 data.
# Cell found in both datasets! Index 152 in 2015 data.
# Cell found in both datasets! Index 153 in 2015 data.
# Cell found in both datasets! Index 154 in 2015 data.
# Cell found in both datasets! Index 155 in 2015 data.
# Cell found in both datasets! Index 156 in 2015 data.
# Cell found in both datasets! Index 157 in 2015 data.
# Cell found in both datasets! Index 158 in 2015 data.
# Cell found in both datasets! Index 159 in 2015 data.
# Cell found in both datasets! Index 160 in 2015 data.
# Cell found in both datasets! Index 161 in 2015 data.
# Cell found in both datasets! Index 162 in 2015 data.
# Cell found in both datasets! Index 163 in 2015 data.
# Cell found in both datasets! Index 164 in 2015 data.
# Cell found in both datasets! Index 165 in 2015 data.
# Cell found in both datasets! Index 166 in 2015 data.
# Cell found in both datasets! Index 167 in 2015 data.
# Cell found in both datasets! Index 168 in 2015 data.
# Cell found in both datasets! Index 169 in 2015 data.
# Cell found in both datasets! Index 170 in 2015 data.
# Cell found in both datasets! Index 171 in 2015 data.
# Cell found in both datasets! Index 172 in 2015 data.
# Cell found in both datasets! Index 173 in 2015 data.
# Cell found in both datasets! Index 174 in 2015 data.
# Cell found in both datasets! Index 175 in 2015 data.
# Cell found in both datasets! Index 176 in 2015 data.
# Cell found in both datasets! Index 177 in 2015 data.
# Cell found in both datasets! Index 178 in 2015 data.
# Cell found in both datasets! Index 179 in 2015 data.
# Cell found in both datasets! Index 180 in 2015 data.
# Cell found in both datasets! Index 181 in 2015 data.
# Cell found in both datasets! Index 182 in 2015 data.
# Cell found in both datasets! Index 183 in 2015 data.
# Cell found in both datasets! Index 184 in 2015 data.
# Cell found in both datasets! Index 185 in 2015 data.
# Cell found in both datasets! Index 186 in 2015 data.
# Cell found in both datasets! Index 187 in 2015 data.
# Cell found in both datasets! Index 188 in 2015 data.
# Cell found in both datasets! Index 189 in 2015 data.
# Cell found in both datasets! Index 190 in 2015 data.
# Cell found in both datasets! Index 191 in 2015 data.
# Cell found in both datasets! Index 192 in 2015 data.
# Cell found in both datasets! Index 193 in 2015 data.
# Cell found in both datasets! Index 194 in 2015 data.
# Cell found in both datasets! Index 195 in 2015 data.
# Cell found in both datasets! Index 196 in 2015 data.
# Cell found in both datasets! Index 197 in 2015 data.
# Cell found in both datasets! Index 198 in 2015 data.
# Cell found in both datasets! Index 199 in 2015 data.
# Cell found in both datasets! Index 200 in 2015 data.
# Cell found in both datasets! Index 201 in 2015 data.
# Cell found in both datasets! Index 202 in 2015 data.
# Cell found in both datasets! Index 203 in 2015 data.
# Cell found in both datasets! Index 204 in 2015 data.
# Cell found in both datasets! Index 205 in 2015 data.
# Cell found in both datasets! Index 206 in 2015 data.
# Cell found in both datasets! Index 207 in 2015 data.
# Cell found in both datasets! Index 208 in 2015 data.
# Cell found in both datasets! Index 209 in 2015 data.
# Cell found in both datasets! Index 210 in 2015 data.
# Cell found in both datasets! Index 211 in 2015 data.
# Cell found in both datasets! Index 212 in 2015 data.
# Cell found in both datasets! Index 213 in 2015 data.
# Cell found in both datasets! Index 214 in 2015 data.
# Cell found in both datasets! Index 215 in 2015 data.
# Cell found in both datasets! Index 216 in 2015 data.
# Cell found in both datasets! Index 217 in 2015 data.
# Cell found in both datasets! Index 218 in 2015 data.
# Cell found in both datasets! Index 219 in 2015 data.
# Cell found in both datasets! Index 220 in 2015 data.
# Cell found in both datasets! Index 221 in 2015 data.
# Cell found in both datasets! Index 222 in 2015 data.
# Cell found in both datasets! Index 223 in 2015 data.
# Cell found in both datasets! Index 224 in 2015 data.
# Cell found in both datasets! Index 225 in 2015 data.
# Cell found in both datasets! Index 226 in 2015 data.
# Cell found in both datasets! Index 227 in 2015 data.
# Cell found in both datasets! Index 228 in 2015 data.
# Cell found in both datasets! Index 229 in 2015 data.
# Cell found in both datasets! Index 230 in 2015 data.
# Cell found in both datasets! Index 231 in 2015 data.
# Cell found in both datasets! Index 232 in 2015 data.
# Cell found in both datasets! Index 233 in 2015 data.
# Cell found in both datasets! Index 234 in 2015 data.
# Cell found in both datasets! Index 235 in 2015 data.
# Cell found in both datasets! Index 236 in 2015 data.
# Cell found in both datasets! Index 237 in 2015 data.
# Cell found in both datasets! Index 238 in 2015 data.
# Cell found in both datasets! Index 239 in 2015 data.
# Cell found in both datasets! Index 240 in 2015 data.
# Cell found in both datasets! Index 241 in 2015 data.
# Cell found in both datasets! Index 242 in 2015 data.
# Cell found in both datasets! Index 243 in 2015 data.
# Cell found in both datasets! Index 244 in 2015 data.
# Cell found in both datasets! Index 245 in 2015 data.
# Cell found in both datasets! Index 246 in 2015 data.
# Cell found in both datasets! Index 247 in 2015 data.
# Cell found in both datasets! Index 248 in 2015 data.
# Cell found in both datasets! Index 249 in 2015 data.
# Cell found in both datasets! Index 250 in 2015 data.
# Cell found in both datasets! Index 251 in 2015 data.
# Cell found in both datasets! Index 254 in 2015 data.
# Cell found in both datasets! Index 255 in 2015 data.
# Cell found in both datasets! Index 256 in 2015 data.
# Cell found in both datasets! Index 257 in 2015 data.
# Cell found in both datasets! Index 258 in 2015 data.
# Cell found in both datasets! Index 259 in 2015 data.
# Cell found in both datasets! Index 260 in 2015 data.
# Cell found in both datasets! Index 261 in 2015 data.
# Cell found in both datasets! Index 262 in 2015 data.
# Cell found in both datasets! Index 263 in 2015 data.
# Cell found in both datasets! Index 264 in 2015 data.
# Cell found in both datasets! Index 265 in 2015 data.
# Cell found in both datasets! Index 266 in 2015 data.
# Cell found in both datasets! Index 267 in 2015 data.
# Cell found in both datasets! Index 268 in 2015 data.
# Cell found in both datasets! Index 269 in 2015 data.
# Cell found in both datasets! Index 270 in 2015 data.
# Cell found in both datasets! Index 271 in 2015 data.
# Cell found in both datasets! Index 272 in 2015 data.
# Cell found in both datasets! Index 273 in 2015 data.
# Cell found in both datasets! Index 274 in 2015 data.
# Cell found in both datasets! Index 275 in 2015 data.
# Cell found in both datasets! Index 276 in 2015 data.
# Cell found in both datasets! Index 277 in 2015 data.
# Cell found in both datasets! Index 278 in 2015 data.
# Cell found in both datasets! Index 279 in 2015 data.
# Cell found in both datasets! Index 280 in 2015 data.
# Cell found in both datasets! Index 281 in 2015 data.
# Cell found in both datasets! Index 282 in 2015 data.
# Cell found in both datasets! Index 283 in 2015 data.
# Cell found in both datasets! Index 284 in 2015 data.
# Cell found in both datasets! Index 285 in 2015 data.
# Cell found in both datasets! Index 286 in 2015 data.
# Cell found in both datasets! Index 287 in 2015 data.
# Cell found in both datasets! Index 288 in 2015 data.
# Cell found in both datasets! Index 289 in 2015 data.
# Cell found in both datasets! Index 290 in 2015 data.
# Cell found in both datasets! Index 291 in 2015 data.
# Cell found in both datasets! Index 292 in 2015 data.
# Cell found in both datasets! Index 293 in 2015 data.
# Cell found in both datasets! Index 294 in 2015 data.
# Cell found in both datasets! Index 295 in 2015 data.
# Cell found in both datasets! Index 296 in 2015 data.
# Cell found in both datasets! Index 297 in 2015 data.
# Cell found in both datasets! Index 298 in 2015 data.
# Cell found in both datasets! Index 299 in 2015 data.
# Cell found in both datasets! Index 300 in 2015 data.
# Cell found in both datasets! Index 301 in 2015 data.
# Cell found in both datasets! Index 302 in 2015 data.
# Cell found in both datasets! Index 303 in 2015 data.
# Cell found in both datasets! Index 304 in 2015 data.
# Cell found in both datasets! Index 305 in 2015 data.
# Cell found in both datasets! Index 306 in 2015 data.
# Cell found in both datasets! Index 307 in 2015 data.
# Cell found in both datasets! Index 308 in 2015 data.
# Cell found in both datasets! Index 309 in 2015 data.
# Cell found in both datasets! Index 310 in 2015 data.
# Cell found in both datasets! Index 311 in 2015 data.
# Cell found in both datasets! Index 312 in 2015 data.
# Cell found in both datasets! Index 313 in 2015 data.
# Cell found in both datasets! Index 314 in 2015 data.
# Cell found in both datasets! Index 315 in 2015 data.
# Cell found in both datasets! Index 316 in 2015 data.
# Cell found in both datasets! Index 317 in 2015 data.
# Cell found in both datasets! Index 318 in 2015 data.
# Cell found in both datasets! Index 319 in 2015 data.
# Cell found in both datasets! Index 320 in 2015 data.
# Cell found in both datasets! Index 321 in 2015 data.
# Cell found in both datasets! Index 322 in 2015 data.
# Cell found in both datasets! Index 323 in 2015 data.
# Cell found in both datasets! Index 324 in 2015 data.
# Cell found in both datasets! Index 325 in 2015 data.
# Cell found in both datasets! Index 326 in 2015 data.
# Cell found in both datasets! Index 327 in 2015 data.
# Cell found in both datasets! Index 335 in 2015 data.
# Cell found in both datasets! Index 336 in 2015 data.
# Cell found in both datasets! Index 337 in 2015 data.
# Cell found in both datasets! Index 338 in 2015 data.
# Cell found in both datasets! Index 339 in 2015 data.
# Cell found in both datasets! Index 340 in 2015 data.
# Cell found in both datasets! Index 341 in 2015 data.
# Cell found in both datasets! Index 342 in 2015 data.
# Cell found in both datasets! Index 343 in 2015 data.
# Cell found in both datasets! Index 344 in 2015 data.
# Cell found in both datasets! Index 345 in 2015 data.
# Cell found in both datasets! Index 346 in 2015 data.
# Cell found in both datasets! Index 347 in 2015 data.
# Cell found in both datasets! Index 348 in 2015 data.
# Cell found in both datasets! Index 349 in 2015 data.
# Cell found in both datasets! Index 350 in 2015 data.
# Cell found in both datasets! Index 351 in 2015 data.
# Cell found in both datasets! Index 352 in 2015 data.
# Cell found in both datasets! Index 353 in 2015 data.
# Cell found in both datasets! Index 354 in 2015 data.
# Cell found in both datasets! Index 355 in 2015 data.
# Cell found in both datasets! Index 356 in 2015 data.
# Cell found in both datasets! Index 357 in 2015 data.
# Cell found in both datasets! Index 358 in 2015 data.
# Cell found in both datasets! Index 359 in 2015 data.
# Cell found in both datasets! Index 360 in 2015 data.
# Cell found in both datasets! Index 361 in 2015 data.
# Cell found in both datasets! Index 362 in 2015 data.
# Cell found in both datasets! Index 363 in 2015 data.
# Cell found in both datasets! Index 364 in 2015 data.
# Cell found in both datasets! Index 365 in 2015 data.
# Cell found in both datasets! Index 366 in 2015 data.
# Cell found in both datasets! Index 367 in 2015 data.
# Cell found in both datasets! Index 368 in 2015 data.
# Cell found in both datasets! Index 369 in 2015 data.
# Cell found in both datasets! Index 370 in 2015 data.
# Cell found in both datasets! Index 371 in 2015 data.
# Cell found in both datasets! Index 372 in 2015 data.
# Cell found in both datasets! Index 373 in 2015 data.
# Cell found in both datasets! Index 374 in 2015 data.
# Cell found in both datasets! Index 375 in 2015 data.
# Cell found in both datasets! Index 376 in 2015 data.
# Cell found in both datasets! Index 377 in 2015 data.
# Cell found in both datasets! Index 378 in 2015 data.
# Cell found in both datasets! Index 379 in 2015 data.
# Cell found in both datasets! Index 380 in 2015 data.
# Cell found in both datasets! Index 381 in 2015 data.
# Cell found in both datasets! Index 382 in 2015 data.
# Cell found in both datasets! Index 383 in 2015 data.
# Cell found in both datasets! Index 384 in 2015 data.
# Cell found in both datasets! Index 385 in 2015 data.
# Cell found in both datasets! Index 386 in 2015 data.
# Cell found in both datasets! Index 387 in 2015 data.
# Cell found in both datasets! Index 388 in 2015 data.
# Cell found in both datasets! Index 389 in 2015 data.
# Cell found in both datasets! Index 390 in 2015 data.
# Cell found in both datasets! Index 391 in 2015 data.
# Cell found in both datasets! Index 392 in 2015 data.
# Cell found in both datasets! Index 393 in 2015 data.
# Cell found in both datasets! Index 394 in 2015 data.
# Cell found in both datasets! Index 395 in 2015 data.
# Cell found in both datasets! Index 396 in 2015 data.
# Cell found in both datasets! Index 397 in 2015 data.
# Cell found in both datasets! Index 398 in 2015 data.
# Cell found in both datasets! Index 399 in 2015 data.
# Cell found in both datasets! Index 400 in 2015 data.
# Cell found in both datasets! Index 401 in 2015 data.
# Cell found in both datasets! Index 402 in 2015 data.
# Cell found in both datasets! Index 403 in 2015 data.
# Cell found in both datasets! Index 404 in 2015 data.
# Cell found in both datasets! Index 405 in 2015 data.
# Cell found in both datasets! Index 406 in 2015 data.
# Cell found in both datasets! Index 407 in 2015 data.
# Cell found in both datasets! Index 408 in 2015 data.
# Cell found in both datasets! Index 409 in 2015 data.
# Cell found in both datasets! Index 410 in 2015 data.
# Cell found in both datasets! Index 411 in 2015 data.
# Cell found in both datasets! Index 412 in 2015 data.
# Cell found in both datasets! Index 413 in 2015 data.
# Cell found in both datasets! Index 414 in 2015 data.
# Cell found in both datasets! Index 415 in 2015 data.
# Cell found in both datasets! Index 416 in 2015 data.
# Cell found in both datasets! Index 417 in 2015 data.
# Cell found in both datasets! Index 418 in 2015 data.
# Cell found in both datasets! Index 419 in 2015 data.
# Cell found in both datasets! Index 420 in 2015 data.
# Cell found in both datasets! Index 421 in 2015 data.
# Cell found in both datasets! Index 422 in 2015 data.
# Cell found in both datasets! Index 423 in 2015 data.
# Cell found in both datasets! Index 424 in 2015 data.
# Cell found in both datasets! Index 427 in 2015 data.
# Cell found in both datasets! Index 428 in 2015 data.
# Cell found in both datasets! Index 429 in 2015 data.
# Cell found in both datasets! Index 430 in 2015 data.
# Cell found in both datasets! Index 431 in 2015 data.
# Cell found in both datasets! Index 432 in 2015 data.
# Cell found in both datasets! Index 433 in 2015 data.
# Cell found in both datasets! Index 434 in 2015 data.
# Cell found in both datasets! Index 435 in 2015 data.
# Cell found in both datasets! Index 436 in 2015 data.
# Cell found in both datasets! Index 437 in 2015 data.
# Cell found in both datasets! Index 438 in 2015 data.
# Cell found in both datasets! Index 441 in 2015 data.
# Cell found in both datasets! Index 443 in 2015 data.
# Cell found in both datasets! Index 444 in 2015 data.
# Cell found in both datasets! Index 446 in 2015 data.
# Cell found in both datasets! Index 447 in 2015 data.
# Cell found in both datasets! Index 448 in 2015 data.
# Cell found in both datasets! Index 449 in 2015 data.
# Cell found in both datasets! Index 450 in 2015 data.
# Cell found in both datasets! Index 453 in 2015 data.
# Cell found in both datasets! Index 454 in 2015 data.
# Cell found in both datasets! Index 456 in 2015 data.
# Cell found in both datasets! Index 457 in 2015 data.
# Cell found in both datasets! Index 458 in 2015 data.
# Cell found in both datasets! Index 459 in 2015 data.
# Cell found in both datasets! Index 460 in 2015 data.
# Cell found in both datasets! Index 461 in 2015 data.
# Cell found in both datasets! Index 462 in 2015 data.
# Cell found in both datasets! Index 463 in 2015 data.
# Cell found in both datasets! Index 464 in 2015 data.
# Cell found in both datasets! Index 465 in 2015 data.
# Cell found in both datasets! Index 466 in 2015 data.
# Cell found in both datasets! Index 467 in 2015 data.
# Cell found in both datasets! Index 468 in 2015 data.
# Cell found in both datasets! Index 469 in 2015 data.
# Cell found in both datasets! Index 470 in 2015 data.
# Cell found in both datasets! Index 471 in 2015 data.
# Cell found in both datasets! Index 472 in 2015 data.
# Cell found in both datasets! Index 473 in 2015 data.
# Cell found in both datasets! Index 474 in 2015 data.
# Cell found in both datasets! Index 475 in 2015 data.
# Cell found in both datasets! Index 476 in 2015 data.
# Cell found in both datasets! Index 477 in 2015 data.
# Cell found in both datasets! Index 478 in 2015 data.
# Cell found in both datasets! Index 479 in 2015 data.
# Cell found in both datasets! Index 480 in 2015 data.
# Cell found in both datasets! Index 481 in 2015 data.
# Cell found in both datasets! Index 482 in 2015 data.
# Cell found in both datasets! Index 483 in 2015 data.
# Cell found in both datasets! Index 484 in 2015 data.
# Cell found in both datasets! Index 485 in 2015 data.
# Cell found in both datasets! Index 486 in 2015 data.
# Cell found in both datasets! Index 487 in 2015 data.
# Cell found in both datasets! Index 488 in 2015 data.
# Cell found in both datasets! Index 489 in 2015 data.
# Cell found in both datasets! Index 490 in 2015 data.
# Cell found in both datasets! Index 491 in 2015 data.
# Cell found in both datasets! Index 492 in 2015 data.
# Cell found in both datasets! Index 493 in 2015 data.
# Cell found in both datasets! Index 494 in 2015 data.
# Cell found in both datasets! Index 495 in 2015 data.
# Cell found in both datasets! Index 496 in 2015 data.
# Cell found in both datasets! Index 497 in 2015 data.
# Cell found in both datasets! Index 499 in 2015 data.
# Cell found in both datasets! Index 500 in 2015 data.
# Cell found in both datasets! Index 501 in 2015 data.
# Cell found in both datasets! Index 502 in 2015 data.
# Cell found in both datasets! Index 503 in 2015 data.
# Cell found in both datasets! Index 504 in 2015 data.
# Cell found in both datasets! Index 505 in 2015 data.
# Cell found in both datasets! Index 506 in 2015 data.
# Cell found in both datasets! Index 507 in 2015 data.
# Cell found in both datasets! Index 508 in 2015 data.
# Cell found in both datasets! Index 509 in 2015 data.
# Cell found in both datasets! Index 510 in 2015 data.
# Cell found in both datasets! Index 511 in 2015 data.
# Cell found in both datasets! Index 512 in 2015 data.
# Cell found in both datasets! Index 513 in 2015 data.
# Cell found in both datasets! Index 514 in 2015 data.
# Cell found in both datasets! Index 515 in 2015 data.
# Cell found in both datasets! Index 516 in 2015 data.
# Cell found in both datasets! Index 517 in 2015 data.
# Cell found in both datasets! Index 518 in 2015 data.
# Cell found in both datasets! Index 519 in 2015 data.
# Cell found in both datasets! Index 520 in 2015 data.
# Cell found in both datasets! Index 521 in 2015 data.
# Cell found in both datasets! Index 522 in 2015 data.
# Cell found in both datasets! Index 523 in 2015 data.
# Cell found in both datasets! Index 524 in 2015 data.
# Cell found in both datasets! Index 525 in 2015 data.
# Cell found in both datasets! Index 526 in 2015 data.
# Cell found in both datasets! Index 527 in 2015 data.
# Cell found in both datasets! Index 528 in 2015 data.
# Cell found in both datasets! Index 529 in 2015 data.
# Cell found in both datasets! Index 530 in 2015 data.
# Cell found in both datasets! Index 531 in 2015 data.
# Cell found in both datasets! Index 537 in 2015 data.
# Cell found in both datasets! Index 538 in 2015 data.
# Cell found in both datasets! Index 539 in 2015 data.
# Cell found in both datasets! Index 540 in 2015 data.
# Cell found in both datasets! Index 541 in 2015 data.
# Cell found in both datasets! Index 542 in 2015 data.
# Cell found in both datasets! Index 543 in 2015 data.
# Cell found in both datasets! Index 544 in 2015 data.
# Cell found in both datasets! Index 545 in 2015 data.
# Cell found in both datasets! Index 546 in 2015 data.
# Cell found in both datasets! Index 547 in 2015 data.
# Cell found in both datasets! Index 548 in 2015 data.
# Cell found in both datasets! Index 549 in 2015 data.
# Cell found in both datasets! Index 550 in 2015 data.
# Cell found in both datasets! Index 551 in 2015 data.
# Cell found in both datasets! Index 552 in 2015 data.
# Cell found in both datasets! Index 553 in 2015 data.
# Cell found in both datasets! Index 554 in 2015 data.
# Cell found in both datasets! Index 555 in 2015 data.
# Cell found in both datasets! Index 556 in 2015 data.
# Cell found in both datasets! Index 557 in 2015 data.
# Cell found in both datasets! Index 558 in 2015 data.
# Cell found in both datasets! Index 559 in 2015 data.
# Cell found in both datasets! Index 560 in 2015 data.
# Cell found in both datasets! Index 561 in 2015 data.
# Cell found in both datasets! Index 562 in 2015 data.
# Cell found in both datasets! Index 563 in 2015 data.
# Cell found in both datasets! Index 564 in 2015 data.
# Cell found in both datasets! Index 565 in 2015 data.
# Cell found in both datasets! Index 582 in 2015 data.
# Cell found in both datasets! Index 583 in 2015 data.
# Cell found in both datasets! Index 584 in 2015 data.
# Cell found in both datasets! Index 585 in 2015 data.
# Cell found in both datasets! Index 586 in 2015 data.
# Cell found in both datasets! Index 587 in 2015 data.
# Cell found in both datasets! Index 588 in 2015 data.
# Cell found in both datasets! Index 589 in 2015 data.
# Cell found in both datasets! Index 590 in 2015 data.
# Cell found in both datasets! Index 591 in 2015 data.
# Cell found in both datasets! Index 592 in 2015 data.
# Cell found in both datasets! Index 593 in 2015 data.
# Cell found in both datasets! Index 594 in 2015 data.
# Cell found in both datasets! Index 595 in 2015 data.
# Cell found in both datasets! Index 596 in 2015 data.
# Cell found in both datasets! Index 597 in 2015 data.
# Cell found in both datasets! Index 609 in 2015 data.
# Cell found in both datasets! Index 610 in 2015 data.
# Cell found in both datasets! Index 611 in 2015 data.
# Cell found in both datasets! Index 612 in 2015 data.
# Cell found in both datasets! Index 613 in 2015 data.
# Cell found in both datasets! Index 614 in 2015 data.
# Cell found in both datasets! Index 615 in 2015 data.
# Cell found in both datasets! Index 616 in 2015 data.
# Cell found in both datasets! Index 617 in 2015 data.
# Cell found in both datasets! Index 618 in 2015 data.
# Cell found in both datasets! Index 619 in 2015 data.
# Cell found in both datasets! Index 620 in 2015 data.
# Cell found in both datasets! Index 621 in 2015 data.
# Cell found in both datasets! Index 622 in 2015 data.
# Cell found in both datasets! Index 623 in 2015 data.
# Cell found in both datasets! Index 624 in 2015 data.
# Cell found in both datasets! Index 625 in 2015 data.
# Cell found in both datasets! Index 626 in 2015 data.
# Cell found in both datasets! Index 627 in 2015 data.
# Cell found in both datasets! Index 628 in 2015 data.
# Cell found in both datasets! Index 629 in 2015 data.
# Cell found in both datasets! Index 630 in 2015 data.
# Cell found in both datasets! Index 631 in 2015 data.
# Cell found in both datasets! Index 632 in 2015 data.
# Cell found in both datasets! Index 633 in 2015 data.
# Cell found in both datasets! Index 634 in 2015 data.
# Cell found in both datasets! Index 635 in 2015 data.
# Cell found in both datasets! Index 636 in 2015 data.
# Cell found in both datasets! Index 637 in 2015 data.
# Cell found in both datasets! Index 638 in 2015 data.
# Cell found in both datasets! Index 639 in 2015 data.
# Cell found in both datasets! Index 640 in 2015 data.
# Cell found in both datasets! Index 641 in 2015 data.
# Cell found in both datasets! Index 642 in 2015 data.
# Cell found in both datasets! Index 643 in 2015 data.
# Cell found in both datasets! Index 644 in 2015 data.
# Cell found in both datasets! Index 645 in 2015 data.
# Cell found in both datasets! Index 646 in 2015 data.
# Cell found in both datasets! Index 647 in 2015 data.
# Cell found in both datasets! Index 648 in 2015 data.
# Cell found in both datasets! Index 649 in 2015 data.
# Cell found in both datasets! Index 650 in 2015 data.
# Cell found in both datasets! Index 651 in 2015 data.
# Cell found in both datasets! Index 652 in 2015 data.
# Cell found in both datasets! Index 653 in 2015 data.
# Cell found in both datasets! Index 654 in 2015 data.
# Cell found in both datasets! Index 655 in 2015 data.
# Cell found in both datasets! Index 656 in 2015 data.
# Cell found in both datasets! Index 657 in 2015 data.
# Cell found in both datasets! Index 658 in 2015 data.
# Cell found in both datasets! Index 659 in 2015 data.
# Cell found in both datasets! Index 660 in 2015 data.
# Cell found in both datasets! Index 661 in 2015 data.
# Cell found in both datasets! Index 662 in 2015 data.
# Cell found in both datasets! Index 663 in 2015 data.
# Cell found in both datasets! Index 664 in 2015 data.
# Cell found in both datasets! Index 665 in 2015 data.
# Cell found in both datasets! Index 666 in 2015 data.
# Cell found in both datasets! Index 667 in 2015 data.
# Cell found in both datasets! Index 668 in 2015 data.
# Cell found in both datasets! Index 669 in 2015 data.
# Cell found in both datasets! Index 670 in 2015 data.
# Cell found in both datasets! Index 671 in 2015 data.
# Cell found in both datasets! Index 672 in 2015 data.
# Cell found in both datasets! Index 673 in 2015 data.
# Cell found in both datasets! Index 674 in 2015 data.
# Cell found in both datasets! Index 675 in 2015 data.
# Cell found in both datasets! Index 685 in 2015 data.
# Cell found in both datasets! Index 686 in 2015 data.
# Cell found in both datasets! Index 687 in 2015 data.
# Cell found in both datasets! Index 688 in 2015 data.
# Cell found in both datasets! Index 689 in 2015 data.
# Cell found in both datasets! Index 690 in 2015 data.
# Cell found in both datasets! Index 691 in 2015 data.
# Cell found in both datasets! Index 692 in 2015 data.
# Cell found in both datasets! Index 693 in 2015 data.
# Cell found in both datasets! Index 694 in 2015 data.
# Cell found in both datasets! Index 695 in 2015 data.
# Cell found in both datasets! Index 696 in 2015 data.
# Cell found in both datasets! Index 697 in 2015 data.
# Cell found in both datasets! Index 698 in 2015 data.
# Cell found in both datasets! Index 699 in 2015 data.
# Cell found in both datasets! Index 700 in 2015 data.
# Cell found in both datasets! Index 701 in 2015 data.
# Cell found in both datasets! Index 702 in 2015 data.
# Cell found in both datasets! Index 703 in 2015 data.
# Cell found in both datasets! Index 704 in 2015 data.
# Cell found in both datasets! Index 705 in 2015 data.
# Cell found in both datasets! Index 706 in 2015 data.
# Cell found in both datasets! Index 707 in 2015 data.
# Cell found in both datasets! Index 708 in 2015 data.
# Cell found in both datasets! Index 709 in 2015 data.
# Cell found in both datasets! Index 710 in 2015 data.
# Cell found in both datasets! Index 711 in 2015 data.
# Cell found in both datasets! Index 712 in 2015 data.
# Cell found in both datasets! Index 713 in 2015 data.
# Cell found in both datasets! Index 714 in 2015 data.
# Cell found in both datasets! Index 718 in 2015 data.
# Cell found in both datasets! Index 719 in 2015 data.
# Cell found in both datasets! Index 720 in 2015 data.
# Cell found in both datasets! Index 721 in 2015 data.
# Cell found in both datasets! Index 722 in 2015 data.
# Cell found in both datasets! Index 723 in 2015 data.
# Cell found in both datasets! Index 724 in 2015 data.
# Cell found in both datasets! Index 725 in 2015 data.
# Cell found in both datasets! Index 726 in 2015 data.
# Cell found in both datasets! Index 727 in 2015 data.
# Cell found in both datasets! Index 728 in 2015 data.
# Cell found in both datasets! Index 729 in 2015 data.
# Cell found in both datasets! Index 730 in 2015 data.
# Cell found in both datasets! Index 731 in 2015 data.
# Cell found in both datasets! Index 732 in 2015 data.
# Cell found in both datasets! Index 733 in 2015 data.
# Cell found in both datasets! Index 734 in 2015 data.
# Cell found in both datasets! Index 735 in 2015 data.
# Cell found in both datasets! Index 736 in 2015 data.
# Cell found in both datasets! Index 737 in 2015 data.
# Cell found in both datasets! Index 738 in 2015 data.
# Cell found in both datasets! Index 739 in 2015 data.
# Cell found in both datasets! Index 740 in 2015 data.
# Cell found in both datasets! Index 741 in 2015 data.
# Cell found in both datasets! Index 742 in 2015 data.
# Cell found in both datasets! Index 743 in 2015 data.
# Cell found in both datasets! Index 744 in 2015 data.
# Cell found in both datasets! Index 745 in 2015 data.
# Cell found in both datasets! Index 746 in 2015 data.
# Cell found in both datasets! Index 747 in 2015 data.
# Cell found in both datasets! Index 748 in 2015 data.
# Cell found in both datasets! Index 749 in 2015 data.
# Cell found in both datasets! Index 750 in 2015 data.
# Cell found in both datasets! Index 751 in 2015 data.
# Cell found in both datasets! Index 752 in 2015 data.
# Cell found in both datasets! Index 753 in 2015 data.
# Cell found in both datasets! Index 754 in 2015 data.
# Cell found in both datasets! Index 755 in 2015 data.
# Cell found in both datasets! Index 756 in 2015 data.
# Cell found in both datasets! Index 757 in 2015 data.
# Cell found in both datasets! Index 758 in 2015 data.
# Cell found in both datasets! Index 759 in 2015 data.
# Cell found in both datasets! Index 760 in 2015 data.
# Cell found in both datasets! Index 761 in 2015 data.
# Cell found in both datasets! Index 762 in 2015 data.
# Cell found in both datasets! Index 763 in 2015 data.
# Cell found in both datasets! Index 764 in 2015 data.
# Cell found in both datasets! Index 765 in 2015 data.
# Cell found in both datasets! Index 766 in 2015 data.
# Cell found in both datasets! Index 767 in 2015 data.
# Cell found in both datasets! Index 768 in 2015 data.
# Cell found in both datasets! Index 769 in 2015 data.
# Cell found in both datasets! Index 770 in 2015 data.
# Cell found in both datasets! Index 771 in 2015 data.
# Cell found in both datasets! Index 772 in 2015 data.
# Cell found in both datasets! Index 773 in 2015 data.
# Cell found in both datasets! Index 774 in 2015 data.
# Cell found in both datasets! Index 775 in 2015 data.
# Cell found in both datasets! Index 776 in 2015 data.
# Cell found in both datasets! Index 777 in 2015 data.
# Cell found in both datasets! Index 778 in 2015 data.
# Cell found in both datasets! Index 779 in 2015 data.
# Cell found in both datasets! Index 780 in 2015 data.
# Cell found in both datasets! Index 781 in 2015 data.
# Cell found in both datasets! Index 782 in 2015 data.
# Cell found in both datasets! Index 783 in 2015 data.
# Cell found in both datasets! Index 784 in 2015 data.
# Cell found in both datasets! Index 785 in 2015 data.
# Cell found in both datasets! Index 786 in 2015 data.
# Cell found in both datasets! Index 787 in 2015 data.
# Cell found in both datasets! Index 788 in 2015 data.
# Cell found in both datasets! Index 789 in 2015 data.
# Cell found in both datasets! Index 790 in 2015 data.
# Cell found in both datasets! Index 791 in 2015 data.
# Cell found in both datasets! Index 792 in 2015 data.
# Cell found in both datasets! Index 793 in 2015 data.
# Cell found in both datasets! Index 794 in 2015 data.
# Cell found in both datasets! Index 795 in 2015 data.
# Cell found in both datasets! Index 796 in 2015 data.
# Cell found in both datasets! Index 797 in 2015 data.
# Cell found in both datasets! Index 798 in 2015 data.
# Cell found in both datasets! Index 799 in 2015 data.
# Cell found in both datasets! Index 800 in 2015 data.
# Cell found in both datasets! Index 801 in 2015 data.
# Cell found in both datasets! Index 802 in 2015 data.
# Cell found in both datasets! Index 803 in 2015 data.
# Cell found in both datasets! Index 804 in 2015 data.
# Cell found in both datasets! Index 805 in 2015 data.
# Cell found in both datasets! Index 806 in 2015 data.
# Cell found in both datasets! Index 807 in 2015 data.
# Cell found in both datasets! Index 808 in 2015 data.
# Cell found in both datasets! Index 809 in 2015 data.
# Cell found in both datasets! Index 810 in 2015 data.
# Cell found in both datasets! Index 811 in 2015 data.
# Cell found in both datasets! Index 812 in 2015 data.
# Cell found in both datasets! Index 828 in 2015 data.
# Cell found in both datasets! Index 829 in 2015 data.
# Cell found in both datasets! Index 830 in 2015 data.
# Cell found in both datasets! Index 831 in 2015 data.
# Cell found in both datasets! Index 832 in 2015 data.
# Cell found in both datasets! Index 833 in 2015 data.
# Cell found in both datasets! Index 834 in 2015 data.
# Cell found in both datasets! Index 835 in 2015 data.
# Cell found in both datasets! Index 836 in 2015 data.
# Cell found in both datasets! Index 837 in 2015 data.
# Cell found in both datasets! Index 838 in 2015 data.
# Cell found in both datasets! Index 839 in 2015 data.
# Cell found in both datasets! Index 840 in 2015 data.
# Cell found in both datasets! Index 841 in 2015 data.
# Cell found in both datasets! Index 842 in 2015 data.
# Cell found in both datasets! Index 843 in 2015 data.
# Cell found in both datasets! Index 844 in 2015 data.
# Cell found in both datasets! Index 845 in 2015 data.
# Cell found in both datasets! Index 846 in 2015 data.
# Cell found in both datasets! Index 847 in 2015 data.
# Cell found in both datasets! Index 848 in 2015 data.
# Cell found in both datasets! Index 849 in 2015 data.
# Cell found in both datasets! Index 850 in 2015 data.
# Cell found in both datasets! Index 851 in 2015 data.
# Cell found in both datasets! Index 852 in 2015 data.
# Cell found in both datasets! Index 853 in 2015 data.
# Cell found in both datasets! Index 854 in 2015 data.
# Cell found in both datasets! Index 855 in 2015 data.
# Cell found in both datasets! Index 856 in 2015 data.
# Cell found in both datasets! Index 857 in 2015 data.
# Cell found in both datasets! Index 858 in 2015 data.
# Cell found in both datasets! Index 859 in 2015 data.
# Cell found in both datasets! Index 860 in 2015 data.
# Cell found in both datasets! Index 861 in 2015 data.
# Cell found in both datasets! Index 862 in 2015 data.
# Cell found in both datasets! Index 863 in 2015 data.
# Cell found in both datasets! Index 864 in 2015 data.
# Cell found in both datasets! Index 865 in 2015 data.
# Cell found in both datasets! Index 866 in 2015 data.
# Cell found in both datasets! Index 867 in 2015 data.
# Cell found in both datasets! Index 868 in 2015 data.
# Cell found in both datasets! Index 869 in 2015 data.
# Cell found in both datasets! Index 870 in 2015 data.
# Cell found in both datasets! Index 871 in 2015 data.
# Cell found in both datasets! Index 872 in 2015 data.
# Cell found in both datasets! Index 873 in 2015 data.
# Cell found in both datasets! Index 874 in 2015 data.
# Cell found in both datasets! Index 875 in 2015 data.
# Cell found in both datasets! Index 876 in 2015 data.
# Cell found in both datasets! Index 877 in 2015 data.
# Cell found in both datasets! Index 878 in 2015 data.
# Cell found in both datasets! Index 879 in 2015 data.
# Cell found in both datasets! Index 880 in 2015 data.
# Cell found in both datasets! Index 881 in 2015 data.
# Cell found in both datasets! Index 882 in 2015 data.
# Cell found in both datasets! Index 883 in 2015 data.
# Cell found in both datasets! Index 884 in 2015 data.
# Cell found in both datasets! Index 885 in 2015 data.
# Cell found in both datasets! Index 886 in 2015 data.
# Cell found in both datasets! Index 887 in 2015 data.
# Cell found in both datasets! Index 888 in 2015 data.
# Cell found in both datasets! Index 889 in 2015 data.
# Cell found in both datasets! Index 890 in 2015 data.
# Cell found in both datasets! Index 891 in 2015 data.
# Cell found in both datasets! Index 892 in 2015 data.
# Cell found in both datasets! Index 893 in 2015 data.
# Cell found in both datasets! Index 894 in 2015 data.
# Cell found in both datasets! Index 895 in 2015 data.
# Cell found in both datasets! Index 896 in 2015 data.
# Cell found in both datasets! Index 897 in 2015 data.
# Cell found in both datasets! Index 898 in 2015 data.
# Cell found in both datasets! Index 899 in 2015 data.
# Cell found in both datasets! Index 900 in 2015 data.
# Cell found in both datasets! Index 901 in 2015 data.
# Cell found in both datasets! Index 902 in 2015 data.
# Cell found in both datasets! Index 903 in 2015 data.
# Cell found in both datasets! Index 904 in 2015 data.
# Cell found in both datasets! Index 905 in 2015 data.
# Cell found in both datasets! Index 906 in 2015 data.
# Cell found in both datasets! Index 907 in 2015 data.
# Cell found in both datasets! Index 908 in 2015 data.
# Cell found in both datasets! Index 909 in 2015 data.
# Cell found in both datasets! Index 910 in 2015 data.
# Cell found in both datasets! Index 911 in 2015 data.
# Cell found in both datasets! Index 912 in 2015 data.
# Cell found in both datasets! Index 913 in 2015 data.
# Cell found in both datasets! Index 914 in 2015 data.
# Cell found in both datasets! Index 915 in 2015 data.
# Cell found in both datasets! Index 916 in 2015 data.
# Cell found in both datasets! Index 917 in 2015 data.
# Cell found in both datasets! Index 918 in 2015 data.
# Cell found in both datasets! Index 923 in 2015 data.
# Cell found in both datasets! Index 924 in 2015 data.
# Cell found in both datasets! Index 925 in 2015 data.
# Cell found in both datasets! Index 926 in 2015 data.
# Cell found in both datasets! Index 927 in 2015 data.
# Cell found in both datasets! Index 928 in 2015 data.
# Cell found in both datasets! Index 929 in 2015 data.
# Cell found in both datasets! Index 930 in 2015 data.
# Cell found in both datasets! Index 931 in 2015 data.
# Cell found in both datasets! Index 932 in 2015 data.
# Cell found in both datasets! Index 933 in 2015 data.
# Cell found in both datasets! Index 934 in 2015 data.
# Cell found in both datasets! Index 935 in 2015 data.
# Cell found in both datasets! Index 936 in 2015 data.
# Cell found in both datasets! Index 937 in 2015 data.
# Cell found in both datasets! Index 938 in 2015 data.
# Cell found in both datasets! Index 939 in 2015 data.
# Cell found in both datasets! Index 940 in 2015 data.
# Cell found in both datasets! Index 941 in 2015 data.
# Cell found in both datasets! Index 990 in 2015 data.
# Cell found in both datasets! Index 991 in 2015 data.
# Cell found in both datasets! Index 992 in 2015 data.
# Cell found in both datasets! Index 993 in 2015 data.
# Cell found in both datasets! Index 994 in 2015 data.
# Cell found in both datasets! Index 995 in 2015 data.
# Cell found in both datasets! Index 996 in 2015 data.
# Cell found in both datasets! Index 997 in 2015 data.
# Cell found in both datasets! Index 998 in 2015 data.
# Cell found in both datasets! Index 999 in 2015 data.
# Cell found in both datasets! Index 1000 in 2015 data.
# Cell found in both datasets! Index 1001 in 2015 data.
# Cell found in both datasets! Index 1002 in 2015 data.
# Cell found in both datasets! Index 1003 in 2015 data.
# Cell found in both datasets! Index 1004 in 2015 data.
# Cell found in both datasets! Index 1005 in 2015 data.
# Cell found in both datasets! Index 1008 in 2015 data.
# Cell found in both datasets! Index 1029 in 2015 data.
# Cell found in both datasets! Index 1030 in 2015 data.
# Cell found in both datasets! Index 1031 in 2015 data.
# Cell found in both datasets! Index 1032 in 2015 data.
# Cell found in both datasets! Index 1033 in 2015 data.
# Cell found in both datasets! Index 1034 in 2015 data.
# Cell found in both datasets! Index 1035 in 2015 data.
# Cell found in both datasets! Index 1036 in 2015 data.
# Cell found in both datasets! Index 1037 in 2015 data.
# Cell found in both datasets! Index 1038 in 2015 data.
# Cell found in both datasets! Index 1039 in 2015 data.
# Cell found in both datasets! Index 1040 in 2015 data.
# Cell found in both datasets! Index 1041 in 2015 data.
# Cell found in both datasets! Index 1042 in 2015 data.
# Cell found in both datasets! Index 1043 in 2015 data.
# Cell found in both datasets! Index 1044 in 2015 data.
# Cell found in both datasets! Index 1045 in 2015 data.
# Cell found in both datasets! Index 1067 in 2015 data.
# Cell found in both datasets! Index 1068 in 2015 data.
# Cell found in both datasets! Index 1069 in 2015 data.
# Cell found in both datasets! Index 1071 in 2015 data.
# Cell found in both datasets! Index 1073 in 2015 data.
# Cell found in both datasets! Index 1074 in 2015 data.
# Cell found in both datasets! Index 1075 in 2015 data.
# Cell found in both datasets! Index 1076 in 2015 data.
# Cell found in both datasets! Index 1077 in 2015 data.
# Cell found in both datasets! Index 1078 in 2015 data.
# Cell found in both datasets! Index 1079 in 2015 data.
# Cell found in both datasets! Index 1080 in 2015 data.
# Cell found in both datasets! Index 1081 in 2015 data.
# Cell found in both datasets! Index 1082 in 2015 data.
# Cell found in both datasets! Index 1083 in 2015 data.
# Cell found in both datasets! Index 1084 in 2015 data.
# Cell found in both datasets! Index 1085 in 2015 data.
# Cell found in both datasets! Index 1086 in 2015 data.
# Cell found in both datasets! Index 1087 in 2015 data.
# Cell found in both datasets! Index 1088 in 2015 data.
# Cell found in both datasets! Index 1089 in 2015 data.
# Cell found in both datasets! Index 1090 in 2015 data.
# Cell found in both datasets! Index 1091 in 2015 data.
# Cell found in both datasets! Index 1092 in 2015 data.
# Cell found in both datasets! Index 1093 in 2015 data.
# Cell found in both datasets! Index 1094 in 2015 data.
# Cell found in both datasets! Index 1095 in 2015 data.
# Cell found in both datasets! Index 1096 in 2015 data.
# Cell found in both datasets! Index 1097 in 2015 data.
# Cell found in both datasets! Index 1098 in 2015 data.
# Cell found in both datasets! Index 1099 in 2015 data.
# Cell found in both datasets! Index 1100 in 2015 data.
# Cell found in both datasets! Index 1101 in 2015 data.
# Cell found in both datasets! Index 1102 in 2015 data.
# Cell found in both datasets! Index 1103 in 2015 data.
# Cell found in both datasets! Index 1104 in 2015 data.
# Cell found in both datasets! Index 1105 in 2015 data.
# Cell found in both datasets! Index 1106 in 2015 data.
# Cell found in both datasets! Index 1107 in 2015 data.
# Cell found in both datasets! Index 1108 in 2015 data.
# Cell found in both datasets! Index 1123 in 2015 data.
# Cell found in both datasets! Index 1124 in 2015 data.
# Cell found in both datasets! Index 1125 in 2015 data.
# Cell found in both datasets! Index 1126 in 2015 data.
# Cell found in both datasets! Index 1127 in 2015 data.
# Cell found in both datasets! Index 1128 in 2015 data.
# ...
# Cell found in both datasets! Index 2176 in 2015 data.
# Cell found in both datasets! Index 2177 in 2015 data.
# Cell found in both datasets! Index 2178 in 2015 data.
# Cell found in both datasets! Index 2179 in 2015 data.
# Cell found in both datasets! Index 2180 in 2015 data.
# Cell found in both datasets! Index 2187 in 2015 data.
# Cell found in both datasets! Index 2188 in 2015 data.
# Cell found in both datasets! Index 2189 in 2015 data.
# Cell found in both datasets! Index 2190 in 2015 data.
# Cell found in both datasets! Index 2191 in 2015 data.
# Cell found in both datasets! Index 2192 in 2015 data.
# Cell found in both datasets! Index 2193 in 2015 data.
# Cell found in both datasets! Index 2194 in 2015 data.
# Cell found in both datasets! Index 2195 in 2015 data.
# Cell found in both datasets! Index 2196 in 2015 data.
# Cell found in both datasets! Index 2197 in 2015 data.
# Cell found in both datasets! Index 2198 in 2015 data.
# Cell found in both datasets! Index 2201 in 2015 data.
# Cell found in both datasets! Index 2202 in 2015 data.
# Cell found in both datasets! Index 2203 in 2015 data.
# Cell found in both datasets! Index 2204 in 2015 data.
# Cell found in both datasets! Index 2205 in 2015 data.
# Cell found in both datasets! Index 2206 in 2015 data.
# Cell found in both datasets! Index 2207 in 2015 data.
# Cell found in both datasets! Index 2208 in 2015 data.
# Cell found in both datasets! Index 2209 in 2015 data.
# Cell found in both datasets! Index 2210 in 2015 data.
# Cell found in both datasets! Index 2211 in 2015 data.
# Cell found in both datasets! Index 2212 in 2015 data.
# Cell found in both datasets! Index 2213 in 2015 data.
# Cell found in both datasets! Index 2214 in 2015 data.
# Cell found in both datasets! Index 2215 in 2015 data.
# Cell found in both datasets! Index 2216 in 2015 data.
# Cell found in both datasets! Index 2217 in 2015 data.
# Cell found in both datasets! Index 2218 in 2015 data.
# Cell found in both datasets! Index 2219 in 2015 data.
# Cell found in both datasets! Index 2220 in 2015 data.
# Cell found in both datasets! Index 2221 in 2015 data.
# Cell found in both datasets! Index 2222 in 2015 data.
# Cell found in both datasets! Index 2223 in 2015 data.
# Cell found in both datasets! Index 2224 in 2015 data.
# Cell found in both datasets! Index 2225 in 2015 data.
# Cell found in both datasets! Index 2226 in 2015 data.
# Cell found in both datasets! Index 2227 in 2015 data.
# Cell found in both datasets! Index 2228 in 2015 data.
# Cell found in both datasets! Index 2229 in 2015 data.
# Cell found in both datasets! Index 2230 in 2015 data.
# Cell found in both datasets! Index 2231 in 2015 data.
# Cell found in both datasets! Index 2232 in 2015 data.
# Cell found in both datasets! Index 2233 in 2015 data.
# Cell found in both datasets! Index 2234 in 2015 data.
# Cell found in both datasets! Index 2235 in 2015 data.
# Cell found in both datasets! Index 2237 in 2015 data.
# Cell found in both datasets! Index 2238 in 2015 data.
# Cell found in both datasets! Index 2239 in 2015 data.
# Cell found in both datasets! Index 2240 in 2015 data.
# Cell found in both datasets! Index 2243 in 2015 data.
# Cell found in both datasets! Index 2244 in 2015 data.
# Cell found in both datasets! Index 2245 in 2015 data.
# Cell found in both datasets! Index 2246 in 2015 data.
# Cell found in both datasets! Index 2247 in 2015 data.
# Cell found in both datasets! Index 2248 in 2015 data.
# Cell found in both datasets! Index 2249 in 2015 data.
# Cell found in both datasets! Index 2250 in 2015 data.
# Cell found in both datasets! Index 2251 in 2015 data.
# Cell found in both datasets! Index 2252 in 2015 data.
# Cell found in both datasets! Index 2253 in 2015 data.
# Cell found in both datasets! Index 2254 in 2015 data.
# Cell found in both datasets! Index 2262 in 2015 data.
# Cell found in both datasets! Index 2263 in 2015 data.
# Cell found in both datasets! Index 2264 in 2015 data.
# Cell found in both datasets! Index 2265 in 2015 data.
# Cell found in both datasets! Index 2266 in 2015 data.
# Cell found in both datasets! Index 2267 in 2015 data.
# Cell found in both datasets! Index 2268 in 2015 data.
# Cell found in both datasets! Index 2269 in 2015 data.
# Cell found in both datasets! Index 2270 in 2015 data.
# Cell found in both datasets! Index 2271 in 2015 data.
# Cell found in both datasets! Index 2272 in 2015 data.
# Cell found in both datasets! Index 2273 in 2015 data.
# Cell found in both datasets! Index 2274 in 2015 data.
# Cell found in both datasets! Index 2275 in 2015 data.
# Cell found in both datasets! Index 2276 in 2015 data.
# Cell found in both datasets! Index 2277 in 2015 data.
# Cell found in both datasets! Index 2278 in 2015 data.
# Cell found in both datasets! Index 2279 in 2015 data.
# Cell found in both datasets! Index 2280 in 2015 data.
# Cell found in both datasets! Index 2298 in 2015 data.
# Cell found in both datasets! Index 2299 in 2015 data.
# Cell found in both datasets! Index 2300 in 2015 data.
# Cell found in both datasets! Index 2301 in 2015 data.
# Cell found in both datasets! Index 2302 in 2015 data.
# Cell found in both datasets! Index 2303 in 2015 data.
# Cell found in both datasets! Index 2304 in 2015 data.
# Cell found in both datasets! Index 2305 in 2015 data.
# Cell found in both datasets! Index 2306 in 2015 data.
# Cell found in both datasets! Index 2307 in 2015 data.
# Cell found in both datasets! Index 2308 in 2015 data.
# Cell found in both datasets! Index 2309 in 2015 data.
# Cell found in both datasets! Index 2322 in 2015 data.
# Cell found in both datasets! Index 2323 in 2015 data.
# Cell found in both datasets! Index 2324 in 2015 data.
# Cell found in both datasets! Index 2325 in 2015 data.
# Cell found in both datasets! Index 2327 in 2015 data.
# Cell found in both datasets! Index 2328 in 2015 data.
# Cell found in both datasets! Index 2329 in 2015 data.
# Cell found in both datasets! Index 2330 in 2015 data.
# Cell found in both datasets! Index 2331 in 2015 data.
# Cell found in both datasets! Index 2332 in 2015 data.
# Cell found in both datasets! Index 2333 in 2015 data.
# Cell found in both datasets! Index 2334 in 2015 data.
# Cell found in both datasets! Index 2335 in 2015 data.
# Cell found in both datasets! Index 2336 in 2015 data.
# Cell found in both datasets! Index 2337 in 2015 data.
# Cell found in both datasets! Index 2338 in 2015 data.
# Cell found in both datasets! Index 2339 in 2015 data.
# Cell found in both datasets! Index 2340 in 2015 data.
# Cell found in both datasets! Index 2341 in 2015 data.
# Cell found in both datasets! Index 2342 in 2015 data.
# Cell found in both datasets! Index 2343 in 2015 data.
# Cell found in both datasets! Index 2349 in 2015 data.
# Cell found in both datasets! Index 2350 in 2015 data.
# Cell found in both datasets! Index 2351 in 2015 data.
# Cell found in both datasets! Index 2352 in 2015 data.
# Cell found in both datasets! Index 2353 in 2015 data.
# Cell found in both datasets! Index 2354 in 2015 data.
# Cell found in both datasets! Index 2355 in 2015 data.
# Cell found in both datasets! Index 2356 in 2015 data.
# Cell found in both datasets! Index 2357 in 2015 data.
# Cell found in both datasets! Index 2358 in 2015 data.
# Cell found in both datasets! Index 2359 in 2015 data.
# Cell found in both datasets! Index 2360 in 2015 data.
# Cell found in both datasets! Index 2361 in 2015 data.
# Cell found in both datasets! Index 2362 in 2015 data.
# Cell found in both datasets! Index 2363 in 2015 data.
# Cell found in both datasets! Index 2364 in 2015 data.
# Cell found in both datasets! Index 2365 in 2015 data.
# Cell found in both datasets! Index 2366 in 2015 data.
# Cell found in both datasets! Index 2367 in 2015 data.
# Cell found in both datasets! Index 2368 in 2015 data.
# Cell found in both datasets! Index 2369 in 2015 data.
# Cell found in both datasets! Index 2370 in 2015 data.
# Cell found in both datasets! Index 2371 in 2015 data.
# Cell found in both datasets! Index 2372 in 2015 data.
# Cell found in both datasets! Index 2373 in 2015 data.
# Cell found in both datasets! Index 2374 in 2015 data.
# Cell found in both datasets! Index 2375 in 2015 data.
# Cell found in both datasets! Index 2376 in 2015 data.
# Cell found in both datasets! Index 2377 in 2015 data.
# Cell found in both datasets! Index 2378 in 2015 data.
# Cell found in both datasets! Index 2379 in 2015 data.
# Cell found in both datasets! Index 2380 in 2015 data.
# Cell found in both datasets! Index 2381 in 2015 data.
# Cell found in both datasets! Index 2382 in 2015 data.
# Cell found in both datasets! Index 2383 in 2015 data.
# Cell found in both datasets! Index 2384 in 2015 data.
# Cell found in both datasets! Index 2385 in 2015 data.
# Cell found in both datasets! Index 2386 in 2015 data.
# Cell found in both datasets! Index 2387 in 2015 data.
# Cell found in both datasets! Index 2388 in 2015 data.
# Cell found in both datasets! Index 2389 in 2015 data.
# Cell found in both datasets! Index 2390 in 2015 data.
# Cell found in both datasets! Index 2391 in 2015 data.
# Cell found in both datasets! Index 2392 in 2015 data.
# Cell found in both datasets! Index 2393 in 2015 data.
# Cell found in both datasets! Index 2394 in 2015 data.
# Cell found in both datasets! Index 2395 in 2015 data.
# Cell found in both datasets! Index 2396 in 2015 data.
# Cell found in both datasets! Index 2397 in 2015 data.
# Cell found in both datasets! Index 2398 in 2015 data.
# Cell found in both datasets! Index 2399 in 2015 data.
# Cell found in both datasets! Index 2400 in 2015 data.
# Cell found in both datasets! Index 2401 in 2015 data.
# Cell found in both datasets! Index 2402 in 2015 data.
# Cell found in both datasets! Index 2403 in 2015 data.
# Cell found in both datasets! Index 2404 in 2015 data.
# Cell found in both datasets! Index 2405 in 2015 data.
# Cell found in both datasets! Index 2406 in 2015 data.
# Cell found in both datasets! Index 2407 in 2015 data.
# Cell found in both datasets! Index 2408 in 2015 data.
# Cell found in both datasets! Index 2409 in 2015 data.
# Cell found in both datasets! Index 2410 in 2015 data.
# Cell found in both datasets! Index 2411 in 2015 data.
# Cell found in both datasets! Index 2412 in 2015 data.
# Cell found in both datasets! Index 2413 in 2015 data.
# Cell found in both datasets! Index 2414 in 2015 data.
# Cell found in both datasets! Index 2415 in 2015 data.
# Cell found in both datasets! Index 2416 in 2015 data.
# Cell found in both datasets! Index 2417 in 2015 data.
# Cell found in both datasets! Index 2419 in 2015 data.
# Cell found in both datasets! Index 2420 in 2015 data.
# Cell found in both datasets! Index 2421 in 2015 data.
# Cell found in both datasets! Index 2422 in 2015 data.
# Cell found in both datasets! Index 2423 in 2015 data.
# Cell found in both datasets! Index 2424 in 2015 data.
# Cell found in both datasets! Index 2425 in 2015 data.
# Cell found in both datasets! Index 2426 in 2015 data.
# Cell found in both datasets! Index 2427 in 2015 data.
# Cell found in both datasets! Index 2428 in 2015 data.
# Cell found in both datasets! Index 2429 in 2015 data.
# Cell found in both datasets! Index 2430 in 2015 data.
# Cell found in both datasets! Index 2431 in 2015 data.
# Cell found in both datasets! Index 2432 in 2015 data.
# Cell found in both datasets! Index 2433 in 2015 data.
# Cell found in both datasets! Index 2434 in 2015 data.
# Cell found in both datasets! Index 2435 in 2015 data.
# Cell found in both datasets! Index 2436 in 2015 data.
# Cell found in both datasets! Index 2437 in 2015 data.
# Cell found in both datasets! Index 2438 in 2015 data.
# Cell found in both datasets! Index 2439 in 2015 data.
# Cell found in both datasets! Index 2440 in 2015 data.
# Cell found in both datasets! Index 2441 in 2015 data.
# Cell found in both datasets! Index 2442 in 2015 data.
# Cell found in both datasets! Index 2443 in 2015 data.
# Cell found in both datasets! Index 2444 in 2015 data.
# Cell found in both datasets! Index 2445 in 2015 data.
# Cell found in both datasets! Index 2446 in 2015 data.
# Cell found in both datasets! Index 2447 in 2015 data.
# Cell found in both datasets! Index 2448 in 2015 data.
# Cell found in both datasets! Index 2449 in 2015 data.
# Cell found in both datasets! Index 2450 in 2015 data.
# Cell found in both datasets! Index 2451 in 2015 data.
# Cell found in both datasets! Index 2452 in 2015 data.
# Cell found in both datasets! Index 2453 in 2015 data.
# Cell found in both datasets! Index 2454 in 2015 data.
# Cell found in both datasets! Index 2455 in 2015 data.
# Cell found in both datasets! Index 2456 in 2015 data.
# Cell found in both datasets! Index 2457 in 2015 data.
# Cell found in both datasets! Index 2458 in 2015 data.
# Cell found in both datasets! Index 2459 in 2015 data.
# Cell found in both datasets! Index 2460 in 2015 data.
# Cell found in both datasets! Index 2461 in 2015 data.
# Cell found in both datasets! Index 2462 in 2015 data.
# Cell found in both datasets! Index 2463 in 2015 data.
# Cell found in both datasets! Index 2464 in 2015 data.
# Cell found in both datasets! Index 2465 in 2015 data.
# Cell found in both datasets! Index 2466 in 2015 data.
# Cell found in both datasets! Index 2467 in 2015 data.
# Cell found in both datasets! Index 2468 in 2015 data.
# Cell found in both datasets! Index 2469 in 2015 data.
# Cell found in both datasets! Index 2470 in 2015 data.
# Cell found in both datasets! Index 2471 in 2015 data.
# Cell found in both datasets! Index 2472 in 2015 data.
# Cell found in both datasets! Index 2473 in 2015 data.
# Cell found in both datasets! Index 2474 in 2015 data.
# Cell found in both datasets! Index 2475 in 2015 data.
# Cell found in both datasets! Index 2476 in 2015 data.
# Cell found in both datasets! Index 2477 in 2015 data.
# Cell found in both datasets! Index 2478 in 2015 data.
# Cell found in both datasets! Index 2479 in 2015 data.
# Cell found in both datasets! Index 2480 in 2015 data.
# Cell found in both datasets! Index 2481 in 2015 data.
# Cell found in both datasets! Index 2482 in 2015 data.
# Cell found in both datasets! Index 2483 in 2015 data.
# Cell found in both datasets! Index 2484 in 2015 data.
# Cell found in both datasets! Index 2485 in 2015 data.
# Cell found in both datasets! Index 2486 in 2015 data.
# Cell found in both datasets! Index 2488 in 2015 data.
# Cell found in both datasets! Index 2489 in 2015 data.
# Cell found in both datasets! Index 2490 in 2015 data.
# Cell found in both datasets! Index 2491 in 2015 data.
# Cell found in both datasets! Index 2492 in 2015 data.
# Cell found in both datasets! Index 2493 in 2015 data.
# Cell found in both datasets! Index 2494 in 2015 data.
# Cell found in both datasets! Index 2495 in 2015 data.
# Cell found in both datasets! Index 2496 in 2015 data.
# Cell found in both datasets! Index 2497 in 2015 data.
# Cell found in both datasets! Index 2524 in 2015 data.
# Cell found in both datasets! Index 2525 in 2015 data.
# Cell found in both datasets! Index 2526 in 2015 data.
# Cell found in both datasets! Index 2527 in 2015 data.
# Cell found in both datasets! Index 2528 in 2015 data.
# Cell found in both datasets! Index 2529 in 2015 data.
# Cell found in both datasets! Index 2530 in 2015 data.
# Cell found in both datasets! Index 2531 in 2015 data.
# Cell found in both datasets! Index 2539 in 2015 data.
# Cell found in both datasets! Index 2540 in 2015 data.
# Cell found in both datasets! Index 2541 in 2015 data.
# Cell found in both datasets! Index 2542 in 2015 data.
# Cell found in both datasets! Index 2543 in 2015 data.
# Cell found in both datasets! Index 2544 in 2015 data.
# Cell found in both datasets! Index 2597 in 2015 data.
# Cell found in both datasets! Index 2598 in 2015 data.
# Cell found in both datasets! Index 2599 in 2015 data.
# Cell found in both datasets! Index 2600 in 2015 data.
# Cell found in both datasets! Index 2601 in 2015 data.
# Cell found in both datasets! Index 2602 in 2015 data.
# Cell found in both datasets! Index 2603 in 2015 data.
# Cell found in both datasets! Index 2605 in 2015 data.
# Cell found in both datasets! Index 2606 in 2015 data.
# Cell found in both datasets! Index 2607 in 2015 data.
# Cell found in both datasets! Index 2608 in 2015 data.
# Cell found in both datasets! Index 2609 in 2015 data.
# Cell found in both datasets! Index 2610 in 2015 data.
# Cell found in both datasets! Index 2611 in 2015 data.
# Cell found in both datasets! Index 2612 in 2015 data.

# %% [markdown]
# ### Preview dataset

# %%
# remove undefinedCondensed class with very low representation
training_data = training_data[training_data["Mitocheck_Phenotypic_Class"] != "UndefinedCondensed"]
training_data = training_data.reset_index(drop=True)
training_data
# Out:
#      Mitocheck_Phenotypic_Class  Location_Center_X  Location_Center_Y  \
# 0            MetaphaseAlignment         572.214286          58.185714
# 1                      Artefact        1117.070423         342.732394
# 2                      Artefact        1116.500000         362.000000
# 3                      Artefact        1106.348485         370.469697
# 4            MetaphaseAlignment         937.692308         521.048077
# ...                         ...                ...                ...
# 5518                 OutOfFocus         383.075269         220.198925
# 5519                 OutOfFocus         975.747253         293.868132
# 5520                 OutOfFocus         898.614815         302.407407
# 5521                 OutOfFocus         946.758621         281.689655
# 5522                 OutOfFocus         998.977099         421.229008
#
#      Metadata_Plate  Metadata_Well  Metadata_Frame  Metadata_Site  \
# 0         LT0066_19            287               1              1
# 1         LT0066_19            287               1              1
# 2         LT0066_19            287               1              1
# 3         LT0066_19            287               1              1
# 4         LT0066_19            287               1              1
# ...             ...            ...             ...            ...
# 5518      LT0601_01            217              49              1
# 5519      LT0603_03              2              49              1
# 5520      LT0603_03              2              49              1
# 5521      LT0603_03              2              49              1
# 5522      LT0603_03              2              49              1
#
#      Metadata_Plate_Map_Name                    Metadata_DNA Metadata_Gene  \
# 0              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 1              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 2              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 3              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# 4              LT0066_19_287   LT0066_19/LT0066_19_287_1.tif        ch-TOG
# ...                      ...                             ...           ...
# 5518           LT0601_01_217  LT0601_01/LT0601_01_217_49.tif         ABCB8
# 5519             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif     failed QC
# 5520             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif     failed QC
# 5521             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif     failed QC
# 5522             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif     failed QC
#
#       ...  efficientnet_1270 efficientnet_1271  efficientnet_1272  \
# 0     ...           1.048350         -0.721622           0.749788
# 1     ...           1.172767         -0.290257          -0.709041
# 2     ...           1.093582         -0.323180          -0.663069
# 3     ...           0.943948         -0.211267          -0.346355
# 4     ...           0.947300         -0.564136           0.333336
# ...   ...                ...               ...                ...
# 5518  ...           0.525202          8.110262           1.777901
# 5519  ...           0.277908          5.959773           2.362540
# 5520  ...           0.553313         10.086836           1.170072
# 5521  ...          -0.152000         11.078217           2.460915
# 5522  ...           0.957360          7.852915           2.886973
#
#       efficientnet_1273  efficientnet_1274  efficientnet_1275  \
# 0             -1.377590           0.454974           0.188488
# 1             -1.431541          -0.063308          -0.412793
# 2             -1.427502          -0.901764          -0.355080
# 3             -1.365543          -0.276932           0.023856
# 4             -1.584454           0.891666           1.223252
# ...                 ...                ...                ...
# 5518          -1.512628          -0.225867          -1.612982
# 5519          -1.000032          -0.723652          -1.460720
# 5520          -1.317000          -0.994644          -1.406541
# 5521          -0.989282          -1.141723          -1.424882
# 5522          -1.147031          -0.557976          -1.454247
#
#       efficientnet_1276  efficientnet_1277  efficientnet_1278  \
# 0              0.141427          -1.553405           2.346107
# 1              0.452684          -1.906647           1.962141
# 2              0.418053          -2.298449           1.098266
# 3              0.376514          -1.700348           1.833686
# 4             -0.359166          -0.826366           2.115734
# ...                 ...                ...                ...
# 5518          -0.679415          -2.581475           0.501395
# 5519          -1.919148          -0.301130           0.779582
# 5520          -0.104613          -0.056216           0.714624
# 5521          -2.959780          -1.999795           0.702134
# 5522           0.038499          -0.374986           0.888749
#
#       efficientnet_1279
# 0             -1.774278
# 1             -0.223039
# 2             -0.069326
# 3             -0.625385
# 4             -1.241848
# ...                 ...
# 5518           1.981009
# 5519           3.084642
# 5520           1.612470
# 5521           2.306039
# 5522           1.141029
#
# [5523 rows x 1292 columns]

# %% [markdown]
# ### Save training data

# %%
training_data_save_dir = pathlib.Path("data/")
training_data_save_dir.mkdir(parents=True, exist_ok=True)

training_data_save_path = pathlib.Path(f"{training_data_save_dir}/training_data.csv.gz")
training_data.to_csv(training_data_save_path, compression="gzip")
