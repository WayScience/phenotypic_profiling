# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import pathlib

# %% [markdown]
# ### Specify version of mitocheck_data to download from

# %%
hash = "3ebd0ca7c288f608e9b23987a8ddbabd5476bd8f"
file_url = f"https://raw.github.com/WayScience/mitocheck_data/{hash}/3.normalize_data/normalized_data/training_data.csv.gz"
print(file_url)
# Out:
# https://raw.github.com/WayScience/mitocheck_data/3ebd0ca7c288f608e9b23987a8ddbabd5476bd8f/3.normalize_data/normalized_data/training_data.csv.gz

# %% [markdown]
# ### Load training data from github

# %%
training_data = pd.read_csv(file_url, compression="gzip", index_col=0)
training_data
# Out:
#      Mitocheck_Phenotypic_Class  \
# 0                         Large
# 1                         Large
# 2                         Large
# 3                         Large
# 4                         Large
# ...                         ...
# 2914                 OutOfFocus
# 2915                 OutOfFocus
# 2916                 OutOfFocus
# 2917                 OutOfFocus
# 2918                 OutOfFocus
#
#                                          Object_Outline  Location_Center_X  \
# 0     [[396 595]\n [395 596]\n [394 596]\n [393 596]...         397.288288
# 1     [[361 563]\n [360 564]\n [359 564]\n [358 564]...         359.535714
# 2     [[379 662]\n [378 663]\n [377 663]\n [376 663]...         383.282051
# 3     [[923 515]\n [922 516]\n [921 516]\n [920 516]...         934.568807
# 4     [[483  96]\n [482  97]\n [481  97]\n [480  98]...         481.007143
# ...                                                 ...                ...
# 2914  [[382 185]\n [381 186]\n [380 186]\n [379 186]...         383.075269
# 2915  [[975 277]\n [974 278]\n [973 278]\n [972 278]...         975.747253
# 2916  [[907 280]\n [906 281]\n [905 281]\n [904 281]...         898.614815
# 2917  [[944 267]\n [943 268]\n [942 268]\n [941 268]...         946.758621
# 2918  [[ 992  398]\n [ 991  399]\n [ 990  399]\n [ 9...         998.977099
#
#       Location_Center_Y Metadata_Plate  Metadata_Well  Metadata_Frame  \
# 0            618.558559      LT0010_27            173              83
# 1            585.062500      LT0010_27            173              83
# 2            685.222222      LT0010_27            173              83
# 3            534.385321      LT0013_38             42              75
# 4            121.978571      LT0013_38             42              75
# ...                 ...            ...            ...             ...
# 2914         220.198925      LT0601_01            217              49
# 2915         293.868132      LT0603_03              2              49
# 2916         302.407407      LT0603_03              2              49
# 2917         281.689655      LT0603_03              2              49
# 2918         421.229008      LT0603_03              2              49
#
#       Metadata_Site Metadata_Plate_Map_Name                    Metadata_DNA  \
# 0                 1           LT0010_27_173  LT0010_27/LT0010_27_173_83.tif
# 1                 1           LT0010_27_173  LT0010_27/LT0010_27_173_83.tif
# 2                 1           LT0010_27_173  LT0010_27/LT0010_27_173_83.tif
# 3                 1            LT0013_38_42   LT0013_38/LT0013_38_42_75.tif
# 4                 1            LT0013_38_42   LT0013_38/LT0013_38_42_75.tif
# ...             ...                     ...                             ...
# 2914              1           LT0601_01_217  LT0601_01/LT0601_01_217_49.tif
# 2915              1             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif
# 2916              1             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif
# 2917              1             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif
# 2918              1             LT0603_03_2    LT0603_03/LT0603_03_2_49.tif
#
#       ... efficientnet_1270  efficientnet_1271 efficientnet_1272  \
# 0     ...          1.527232          -0.388696         -0.715081
# 1     ...         -0.483285          -1.355129         -0.857182
# 2     ...          0.888509           1.351147         -0.648786
# 3     ...         -1.424769          -0.863939         -0.582677
# 4     ...          0.693119          -0.581144         -0.256527
# ...   ...               ...                ...               ...
# 2914  ...          0.525202           8.110262          1.777901
# 2915  ...          0.277908           5.959773          2.362540
# 2916  ...          0.553313          10.086836          1.170072
# 2917  ...         -0.152000          11.078217          2.460915
# 2918  ...          0.957360           7.852915          2.886973
#
#       efficientnet_1273  efficientnet_1274  efficientnet_1275  \
# 0             -0.939058          -0.079103           1.966414
# 1             -0.934520           0.724273           2.254263
# 2              0.264769           0.131170           0.679198
# 3             -0.228617           0.426065           1.906163
# 4             -1.401117          -0.357608           2.607508
# ...                 ...                ...                ...
# 2914          -1.512628          -0.225867          -1.612982
# 2915          -1.000032          -0.723652          -1.460720
# 2916          -1.317000          -0.994644          -1.406541
# 2917          -0.989282          -1.141723          -1.424882
# 2918          -1.147031          -0.557976          -1.454247
#
#       efficientnet_1276  efficientnet_1277  efficientnet_1278  \
# 0             18.714635           0.061156           2.639598
# 1             -0.564988           1.629091          -0.606195
# 2              0.172281           0.341971          -0.582500
# 3              0.193329           0.909489          -1.723110
# 4              6.506821          -1.335764          -0.264039
# ...                 ...                ...                ...
# 2914          -0.679415          -2.581475           0.501395
# 2915          -1.919148          -0.301130           0.779582
# 2916          -0.104613          -0.056216           0.714624
# 2917          -2.959780          -1.999795           0.702134
# 2918           0.038499          -0.374986           0.888749
#
#       efficientnet_1279
# 0             -0.085996
# 1             -0.747432
# 2              0.506617
# 3              0.955596
# 4              0.978577
# ...                 ...
# 2914           1.981009
# 2915           3.084642
# 2916           1.612470
# 2917           2.306039
# 2918           1.141029
#
# [2919 rows x 1293 columns]

# %% [markdown]
# ### Save training data

# %%
training_data_save_dir = pathlib.Path("data/")
training_data_save_dir.mkdir(parents=True, exist_ok=True)

training_data_save_path = pathlib.Path(f"{training_data_save_dir}/training_data.csv.gz")
training_data.to_csv(training_data_save_path, compression="gzip")
