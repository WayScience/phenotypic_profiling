# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import pathlib

# %% [markdown]
# ### Specify version of mitocheck_data to download from

# %%
hash = "19bfa5b0959d6b7536f83e7bb85745ba3edf7ff9"
file_url = f"https://raw.github.com/WayScience/mitocheck_data/{hash}/3.normalize_data/normalized_data/training_data.csv.gz"
print(file_url)
# Out:
# https://raw.github.com/WayScience/mitocheck_data/19bfa5b0959d6b7536f83e7bb85745ba3edf7ff9/3.normalize_data/normalized_data/training_data.csv.gz

# %% [markdown]
# ### Load training data from github

# %%
training_data = pd.read_csv(file_url, compression="gzip", index_col=0)
training_data
# Out:
#      Mitocheck_Phenotypic_Class  Mitocheck_Object_ID  Location_Center_X  \
# 0            MetaphaseAlignment                   11         572.214286
# 1                      Artefact                   66        1117.070423
# 2                      Artefact                   66        1116.500000
# 3                      Artefact                   66        1106.348485
# 4            MetaphaseAlignment                   98         937.692308
# ...                         ...                  ...                ...
# 4648             SmallIrregular                  175        1065.846154
# 4649             SmallIrregular                  179        1095.894737
# 4650             SmallIrregular                  194         323.269231
# 4651             SmallIrregular                  266         368.027397
# 4652             SmallIrregular                  273         348.283784
#
#       Location_Center_Y Metadata_Plate  Metadata_Well  Metadata_Frame  \
# 0             58.185714      LT0066_19            287               1
# 1            342.732394      LT0066_19            287               1
# 2            362.000000      LT0066_19            287               1
# 3            370.469697      LT0066_19            287               1
# 4            521.048077      LT0066_19            287               1
# ...                 ...            ...            ...             ...
# 4648         570.123077      LT0030_17            184              39
# 4649         580.771930      LT0030_17            184              39
# 4650         622.641026      LT0030_17            184              39
# 4651         893.575342      LT0030_17            184              39
# 4652         934.040541      LT0030_17            184              39
#
#       Metadata_Site Metadata_Plate_Map_Name                    Metadata_DNA  \
# 0                 1           LT0066_19_287   LT0066_19/LT0066_19_287_1.tif
# 1                 1           LT0066_19_287   LT0066_19/LT0066_19_287_1.tif
# 2                 1           LT0066_19_287   LT0066_19/LT0066_19_287_1.tif
# 3                 1           LT0066_19_287   LT0066_19/LT0066_19_287_1.tif
# 4                 1           LT0066_19_287   LT0066_19/LT0066_19_287_1.tif
# ...             ...                     ...                             ...
# 4648              1           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif
# 4649              1           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif
# 4650              1           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif
# 4651              1           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif
# 4652              1           LT0030_17_184  LT0030_17/LT0030_17_184_39.tif
#
#       ... efficientnet_1270  efficientnet_1271 efficientnet_1272  \
# 0     ...          1.048350          -0.721622          0.749788
# 1     ...          1.172767          -0.290257         -0.709041
# 2     ...          1.093582          -0.323180         -0.663069
# 3     ...          0.943948          -0.211267         -0.346355
# 4     ...          0.947300          -0.564136          0.333336
# ...   ...               ...                ...               ...
# 4648  ...         -0.691697           0.809051         -0.522286
# 4649  ...          0.014888           2.423067         -0.530521
# 4650  ...          1.127832           0.492408         -0.531921
# 4651  ...          0.410533           1.964066         -0.833740
# 4652  ...         -0.041231           0.998568          0.006131
#
#       efficientnet_1273  efficientnet_1274  efficientnet_1275  \
# 0             -1.377590           0.454974           0.188488
# 1             -1.431541          -0.063308          -0.412793
# 2             -1.427502          -0.901764          -0.355080
# 3             -1.365543          -0.276932           0.023856
# 4             -1.584454           0.891666           1.223252
# ...                 ...                ...                ...
# 4648          -0.956816           0.112946          -0.087137
# 4649          -1.026853           0.021895          -0.550902
# 4650          -0.766331           0.286463           0.493081
# 4651          -0.246026           0.984373           0.755903
# 4652          -0.857846           1.163148           0.904470
#
#       efficientnet_1276  efficientnet_1277  efficientnet_1278  \
# 0              0.141427          -1.553405           2.346107
# 1              0.452684          -1.906647           1.962141
# 2              0.418053          -2.298449           1.098266
# 3              0.376514          -1.700348           1.833686
# 4             -0.359166          -0.826366           2.115734
# ...                 ...                ...                ...
# 4648          -1.078033           0.191389          -0.921300
# 4649          -1.224869          -0.410984          -0.717952
# 4650           0.520599          -0.713538           0.553553
# 4651           0.129754          -0.148277          -0.587435
# 4652          -0.321917           0.480036           0.449932
#
#       efficientnet_1279
# 0             -1.774278
# 1             -0.223039
# 2             -0.069326
# 3             -0.625385
# 4             -1.241848
# ...                 ...
# 4648           1.250694
# 4649           2.297320
# 4650           0.480614
# 4651           2.032008
# 4652           1.926145
#
# [4653 rows x 1293 columns]

# %% [markdown]
# ### Save training data

# %%
training_data_save_dir = pathlib.Path("data/")
training_data_save_dir.mkdir(parents=True, exist_ok=True)

training_data_save_path = pathlib.Path(f"{training_data_save_dir}/training_data.csv.gz")
training_data.to_csv(training_data_save_path, compression="gzip")
