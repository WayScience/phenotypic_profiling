# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import pathlib
import seaborn as sns
import matplotlib.pyplot as plt

import sys
sys.path.append("../utils")
from validate_utils import create_classification_profiles

# %% [markdown]
# ### Load Cell Health Profile Labels

# %%
cell_health_hash = "30ea5de393eb9cfc10b575582aa9f0f857b44c59"
cell_health_labels_link = f"https://raw.github.com/broadinstitute/cell-health/{cell_health_hash}/1.generate-profiles/data/consensus/cell_health_median.tsv.gz"

cell_health_labels = pd.read_csv(cell_health_labels_link, compression="gzip", sep="\t")
cell_health_labels
# Out:
#     Metadata_profile_id Metadata_pert_name Metadata_cell_line  \
# 0             profile_0             AKT1-1               A549
# 1             profile_1             AKT1-2               A549
# 2             profile_2           ARID1B-1               A549
# 3             profile_3           ARID1B-2               A549
# 4             profile_4             ATF4-1               A549
# ..                  ...                ...                ...
# 352         profile_352              TXN-2              HCC44
# 353         profile_353              XBP-1              HCC44
# 354         profile_354              XBP-2              HCC44
# 355         profile_355             YAP1-1              HCC44
# 356         profile_356             YAP1-2              HCC44
#
#      cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# 0            0.008156                                0.587977
# 1            0.056667                                1.264627
# 2            0.111163                                1.092964
# 3           -0.061528                                0.320829
# 4            3.967818                                0.003400
# ..                ...                                     ...
# 352         -0.342210                                0.215623
# 353         -0.247848                                0.564827
# 354         -0.349572                               -0.303116
# 355         -0.240422                                0.408734
# 356         -0.295189                               -0.012185
#
#      cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# 0                             0.018820          0.381501
# 1                             0.241450          0.568443
# 2                             0.151393          0.290203
# 3                            -0.091007          0.141819
# 4                             3.268615         -2.246887
# ..                                 ...               ...
# 352                           0.375192          0.900283
# 353                          -0.422787          0.780852
# 354                          -0.458782          0.434831
# 355                          -0.351545          0.387100
# 356                          -0.167711          0.679324
#
#      cc_all_n_spots_h2ax_mean  cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# 0                    0.176564                                   0.187675
# 1                    0.235304                                   0.372684
# 2                    0.402121                                   0.481700
# 3                   -0.378769                                  -0.288693
# 4                    2.891737                                   2.878938
# ..                        ...                                        ...
# 352                 -0.116349                                  -0.083793
# 353                 -0.074603                                   0.000000
# 354                 -0.157653                                  -0.058808
# 355                 -0.132059                                   0.002797
# 356                 -0.290904                                  -0.190527
#
#      cc_all_nucleus_area_mean  ...  vb_num_live_cells  \
# 0                   -0.170616  ...           0.399842
# 1                   -0.276888  ...           0.101670
# 2                   -0.276980  ...           0.080701
# 3                   -0.108741  ...           0.265754
# 4                    2.853995  ...          -2.343919
# ..                        ...  ...                ...
# 352                  0.207844  ...           1.568620
# 353                 -0.123090  ...           0.344139
# 354                 -0.404611  ...           1.341318
# 355                 -0.059520  ...           0.091803
# 356                  0.141177  ...          -0.026244
#
#      vb_percent_all_apoptosis  vb_percent_caspase_dead_only  vb_percent_dead  \
# 0                    0.000000                     -0.118976        -0.132871
# 1                    0.318027                      0.621374         0.100032
# 2                    0.339100                      0.598093         0.055951
# 3                    0.098699                      0.371930        -0.063935
# 4                    0.000000                     -0.089544         0.141535
# ..                        ...                           ...              ...
# 352                 -0.409888                      0.148385        -0.519448
# 353                  0.172909                      0.839550        -0.212904
# 354                 -0.069684                      0.540557        -0.146842
# 355                 -0.155056                     -0.025451        -0.097891
# 356                 -0.252928                     -0.103726        -0.213906
#
#      vb_percent_dead_only  vb_percent_early_apoptosis  \
# 0               -0.121090                    0.000000
# 1                0.074036                    0.132751
# 2                0.042014                    0.165161
# 3               -0.055160                    0.138654
# 4                0.131393                    0.000000
# ..                    ...                         ...
# 352             -0.372714                   -0.136141
# 353             -0.245979                    0.417994
# 354             -0.288259                   -0.179506
# 355             -0.080691                   -0.227172
# 356             -0.111538                   -0.243663
#
#      vb_percent_late_apoptosis  vb_percent_live  vb_ros_back_mean  vb_ros_mean
# 0                     0.000000         0.132882          0.806970     1.293984
# 1                     0.467027        -0.099917          0.558041     1.151867
# 2                     0.247058        -0.055920         -0.393937     0.103202
# 3                     0.000000         0.063946          0.210005     0.055291
# 4                     0.000000        -0.141397         -0.631390     0.106477
# ..                         ...              ...               ...          ...
# 352                  -0.502358         0.520090          0.182738    -0.116806
# 353                   0.028582         0.213691          0.245257     0.105633
# 354                   0.047976         0.147173          0.744648     0.023499
# 355                  -0.114292         0.098480          0.451868     0.127519
# 356                  -0.220404         0.213375          0.186576     0.106439
#
# [357 rows x 73 columns]

# %% [markdown]
# ### Create Classification Profiles

# %%
cell_health_data_hash = "4ee08b16f4b5c5266309a295b0a1697f0b9540b8"
plate_classifications_dir_link = f"https://github.com/WayScience/cell-health-data/raw/{cell_health_data_hash}/4.classify-features/plate_classifications"
plate_names = ["SQ00014610", "SQ00014611", "SQ00014612", "SQ00014613", "SQ00014614", "SQ00014615", "SQ00014616", "SQ00014617", "SQ00014618"]

cell_line_plates = {
    "A549": ["SQ00014610", "SQ00014611", "SQ00014612"],
    "ES2": ["SQ00014613", "SQ00014614", "SQ00014615"],
    "HCC44": ["SQ00014616", "SQ00014617", "SQ00014618"],
}

classification_profiles = create_classification_profiles(plate_classifications_dir_link, cell_line_plates)
classification_profiles
# Out:
# Creating classification profiles for cell line A549
# Averaging classification across perturbation metadata...
# Creating classification profiles for cell line ES2
# Averaging classification across perturbation metadata...
# Creating classification profiles for cell line HCC44
# Averaging classification across perturbation metadata...
#     Metadata_pert_name Metadata_cell_line     ADCCM  Anaphase  Apoptosis  \
# 0               AKT1-1               A549  0.054932  0.027755   0.021307
# 1               AKT1-2               A549  0.052757  0.026695   0.022417
# 2             ARID1B-1               A549  0.040267  0.028365   0.021202
# 3             ARID1B-2               A549  0.045109  0.030562   0.021584
# 4               ATF4-1               A549  0.026970  0.035827   0.016918
# ..                 ...                ...       ...       ...        ...
# 352              XBP-1              HCC44  0.032277  0.027736   0.029891
# 353              XBP-2              HCC44  0.032669  0.029002   0.031823
# 354             YAP1-1              HCC44  0.034511  0.027847   0.037634
# 355             YAP1-2              HCC44  0.033771  0.028334   0.030037
# 356              EMPTY              HCC44  0.033617  0.026411   0.032180
#
#      Artefact  Binuclear  Elongated     Grape      Hole  Interphase     Large  \
# 0    0.048169   0.116542   0.027095  0.040155  0.030093    0.221322  0.019687
# 1    0.047275   0.113333   0.026610  0.041179  0.034239    0.233669  0.021312
# 2    0.047656   0.119522   0.024333  0.039460  0.035141    0.290153  0.028437
# 3    0.041333   0.123428   0.027050  0.039057  0.028491    0.293695  0.026684
# 4    0.013856   0.090874   0.028103  0.019467  0.016642    0.508466  0.039001
# ..        ...        ...        ...       ...       ...         ...       ...
# 352  0.053386   0.107091   0.041403  0.038645  0.041323    0.282075  0.041348
# 353  0.054948   0.106691   0.039883  0.036857  0.046972    0.265102  0.041838
# 354  0.050009   0.087623   0.043881  0.047348  0.056616    0.191724  0.036977
# 355  0.056260   0.105229   0.038985  0.033854  0.043182    0.256354  0.042508
# 356  0.059076   0.098329   0.038730  0.040853  0.047730    0.230193  0.039745
#
#      Metaphase  MetaphaseAlignment  OutOfFocus  Polylobed  Prometaphase  \
# 0     0.040099            0.037670    0.098610   0.129647      0.041857
# 1     0.039802            0.036686    0.089843   0.128045      0.041199
# 2     0.035434            0.040248    0.044184   0.136870      0.033468
# 3     0.033261            0.043536    0.045784   0.124731      0.036990
# 4     0.016502            0.052635    0.012241   0.061432      0.035789
# ..         ...                 ...         ...        ...           ...
# 352   0.033903            0.048170    0.044153   0.108327      0.035608
# 353   0.035828            0.047439    0.045634   0.112850      0.035914
# 354   0.032514            0.039765    0.137421   0.088149      0.047577
# 355   0.036015            0.045088    0.074877   0.092741      0.042136
# 356   0.033903            0.043848    0.086853   0.109512      0.041988
#
#      SmallIrregular
# 0          0.045061
# 1          0.044936
# 2          0.035259
# 3          0.038706
# 4          0.025276
# ..              ...
# 352        0.034663
# 353        0.036549
# 354        0.040405
# 355        0.040629
# 356        0.037031
#
# [357 rows x 18 columns]

# %%
# combine cell health label profiles and classification profiles on perturbation and cell line
final_profile_dataframe = pd.merge(cell_health_labels, classification_profiles, on=["Metadata_pert_name", "Metadata_cell_line"])
final_profile_dataframe
# Out:
#     Metadata_profile_id Metadata_pert_name Metadata_cell_line  \
# 0             profile_0             AKT1-1               A549
# 1             profile_1             AKT1-2               A549
# 2             profile_2           ARID1B-1               A549
# 3             profile_3           ARID1B-2               A549
# 4             profile_4             ATF4-1               A549
# ..                  ...                ...                ...
# 352         profile_352              TXN-2              HCC44
# 353         profile_353              XBP-1              HCC44
# 354         profile_354              XBP-2              HCC44
# 355         profile_355             YAP1-1              HCC44
# 356         profile_356             YAP1-2              HCC44
#
#      cc_all_high_h2ax  cc_all_large_notround_polynuclear_mean  \
# 0            0.008156                                0.587977
# 1            0.056667                                1.264627
# 2            0.111163                                1.092964
# 3           -0.061528                                0.320829
# 4            3.967818                                0.003400
# ..                ...                                     ...
# 352         -0.342210                                0.215623
# 353         -0.247848                                0.564827
# 354         -0.349572                               -0.303116
# 355         -0.240422                                0.408734
# 356         -0.295189                               -0.012185
#
#      cc_all_large_round_polyploid_mean  cc_all_n_objects  \
# 0                             0.018820          0.381501
# 1                             0.241450          0.568443
# 2                             0.151393          0.290203
# 3                            -0.091007          0.141819
# 4                             3.268615         -2.246887
# ..                                 ...               ...
# 352                           0.375192          0.900283
# 353                          -0.422787          0.780852
# 354                          -0.458782          0.434831
# 355                          -0.351545          0.387100
# 356                          -0.167711          0.679324
#
#      cc_all_n_spots_h2ax_mean  cc_all_n_spots_h2ax_per_nucleus_area_mean  \
# 0                    0.176564                                   0.187675
# 1                    0.235304                                   0.372684
# 2                    0.402121                                   0.481700
# 3                   -0.378769                                  -0.288693
# 4                    2.891737                                   2.878938
# ..                        ...                                        ...
# 352                 -0.116349                                  -0.083793
# 353                 -0.074603                                   0.000000
# 354                 -0.157653                                  -0.058808
# 355                 -0.132059                                   0.002797
# 356                 -0.290904                                  -0.190527
#
#      cc_all_nucleus_area_mean  ...     Grape      Hole  Interphase     Large  \
# 0                   -0.170616  ...  0.040155  0.030093    0.221322  0.019687
# 1                   -0.276888  ...  0.041179  0.034239    0.233669  0.021312
# 2                   -0.276980  ...  0.039460  0.035141    0.290153  0.028437
# 3                   -0.108741  ...  0.039057  0.028491    0.293695  0.026684
# 4                    2.853995  ...  0.019467  0.016642    0.508466  0.039001
# ..                        ...  ...       ...       ...         ...       ...
# 352                  0.207844  ...  0.042297  0.045487    0.242511  0.044597
# 353                 -0.123090  ...  0.038645  0.041323    0.282075  0.041348
# 354                 -0.404611  ...  0.036857  0.046972    0.265102  0.041838
# 355                 -0.059520  ...  0.047348  0.056616    0.191724  0.036977
# 356                  0.141177  ...  0.033854  0.043182    0.256354  0.042508
#
#      Metaphase  MetaphaseAlignment  OutOfFocus  Polylobed  Prometaphase  \
# 0     0.040099            0.037670    0.098610   0.129647      0.041857
# 1     0.039802            0.036686    0.089843   0.128045      0.041199
# 2     0.035434            0.040248    0.044184   0.136870      0.033468
# 3     0.033261            0.043536    0.045784   0.124731      0.036990
# 4     0.016502            0.052635    0.012241   0.061432      0.035789
# ..         ...                 ...         ...        ...           ...
# 352   0.034945            0.048240    0.061386   0.106988      0.041195
# 353   0.033903            0.048170    0.044153   0.108327      0.035608
# 354   0.035828            0.047439    0.045634   0.112850      0.035914
# 355   0.032514            0.039765    0.137421   0.088149      0.047577
# 356   0.036015            0.045088    0.074877   0.092741      0.042136
#
#      SmallIrregular
# 0          0.045061
# 1          0.044936
# 2          0.035259
# 3          0.038706
# 4          0.025276
# ..              ...
# 352        0.040591
# 353        0.034663
# 354        0.036549
# 355        0.040405
# 356        0.040629
#
# [357 rows x 89 columns]

# %% [markdown]
# ### Find Correlation

# %%
correlation_method = "pearson"

# combine cell health label profiles and classification profiles on perturbation and cell line
final_profile_dataframe = pd.merge(cell_health_labels, classification_profiles, on=["Metadata_pert_name", "Metadata_cell_line"])
# find correlation
corr = final_profile_dataframe.corr(method=correlation_method)
# convert correlation to diagram-friendly format
corr_graph = corr.iloc[70:, :70]

# %% [markdown]
# ### Show Correlation with Clustermap

# %%
sns.clustermap(corr_graph, 
            xticklabels=corr_graph.columns,
            yticklabels=corr_graph.index,
            cmap='RdBu_r',
            linewidth=0.5,
            figsize=(20,10))

# %% [markdown]
# ### Save Correlation Data in Tidy Long Format

# %%
corr_data_save_path = pathlib.Path(f"validations/cell_health_{correlation_method}_correlations.tsv")
corr_data_save_path.parents[0].mkdir(parents=True, exist_ok=True)

tidy_data = corr_graph.stack()
tidy_data = pd.DataFrame(tidy_data).reset_index(level=[0,1])
tidy_data.columns = ["Phenotypic_Class", "Cell_Health_Label", "Correlation"]
tidy_data.to_csv(corr_data_save_path, sep="\t")
